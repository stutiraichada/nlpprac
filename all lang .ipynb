# %% [markdown]
# # Ngram any Language

# %%
# Install necessary libraries
# !pip install nltk

import nltk
from nltk.util import ngrams
from nltk.tokenize import word_tokenize
from collections import defaultdict

# Download NLTK data (you may need to run this only once)
nltk.download('punkt')

def create_ngram_model(sentences, n):
    """
    Create an n-gram model from a list of sentences.

    Args:
        sentences (list of str): The sentences to use for the n-gram model.
        n (int): The value of n for the n-gram model.

    Returns:
        ngram_model (dict): The n-gram model as a dictionary.
    """
    ngram_model = defaultdict(lambda: defaultdict(lambda: 0))

    for sentence in sentences:
        tokens = word_tokenize(sentence)  # No need to lower case for Hindi/Marathi/Gujarati
        for ngram in ngrams(tokens, n):
            prefix, suffix = tuple(ngram[:-1]), ngram[-1]
            ngram_model[prefix][suffix] += 1

    # Convert counts to probabilities
    for prefix in ngram_model:
        total_count = float(sum(ngram_model[prefix].values()))
        for suffix in ngram_model[prefix]:
            ngram_model[prefix][suffix] /= total_count

    return ngram_model

def predict_next_word(ngram_model, sentence, n):
    """
    Predict the next word given a sentence based on the n-gram model.

    Args:
        ngram_model (dict): The n-gram model.
        sentence (str): The sentence for which to predict the next word.
        n (int): The value of n for the n-gram model.

    Returns:
        next_word (str): The most probable next word.
    """
    tokens = word_tokenize(sentence)

    if len(tokens) < n - 1:
        return "Not enough context to predict."

    prefix = tuple(tokens[-(n - 1):])

    if prefix not in ngram_model:
        return "No prediction available for this context."

    next_word = max(ngram_model[prefix], key=ngram_model[prefix].get)
    return next_word

def calculate_probability(ngram_model, sentence, n):
    """
    Calculate the probability of a given sentence based on the n-gram model.

    Args:
        ngram_model (dict): The n-gram model.
        sentence (str): The sentence for which to calculate the probability.
        n (int): The value of n for the n-gram model.

    Returns:
        probability (float): The probability of the sentence.
    """
    tokens = word_tokenize(sentence)
    probability = 1.0

    if len(tokens) < n:
        return 0.0

    for i in range(n - 1, len(tokens)):
        prefix = tuple(tokens[i - (n - 1):i])
        suffix = tokens[i]

        if prefix in ngram_model and suffix in ngram_model[prefix]:
            probability *= ngram_model[prefix][suffix]
        else:
            return 0.0

    return probability

def main():
    # Get user input
    n = int(input("Enter the value of n for the n-gram model: "))
    language = input("Enter the language (Hindi, Gujarati, Marathi): ").lower()

    if language == "hindi":
        sentences = input("Enter the Hindi sentences for the corpus (separated by ';'): ").split(';')
    elif language == "gujarati":
        sentences = input("Enter the Gujarati sentences for the corpus (separated by ';'): ").split(';')
    elif language == "marathi":
        sentences = input("Enter the Marathi sentences for the corpus (separated by ';'): ").split(';')
    else:
        print("Unsupported language.")
        return

    test_sentence = input("Enter the sentence to predict the next word: ")

    # Create n-gram model
    ngram_model = create_ngram_model(sentences, n)

    # Calculate probability of a test sentence
    probability = calculate_probability(ngram_model, test_sentence, n)
    print(f"Probability of '{test_sentence}': {probability}")

    # Predict the next word
    next_word = predict_next_word(ngram_model, test_sentence, n)
    print(f"Predicted next word for '{test_sentence}': {next_word}")

if __name__ == "__main__":
    main()
# Out:
# Requirement already satisfied: nltk in c:\users\91636\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\91636\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\91636\anaconda3\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\91636\anaconda3\lib\site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\91636\anaconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\91636\appdata\roaming\python\python311\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\91636\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Unsupported language.

# %% [markdown]
# # Hindi Experiments

# %%
# Install necessary libraries
# !pip install indic-nlp-library
# !pip install stanza

# Import libraries
from indicnlp.tokenize import indic_tokenize
import stanza

# Download the Stanza model for Hindi
stanza.download('hi')

# Define stopwords based on the given text
custom_hindi_stopwords = [
    "में", "की", "का", "और", "है", "को", "के", "से", "हैं", "यह", "ने", "जिसमें", "किए",
    "जिन", "जो", "का", "की", "यदि", "का", "पर", "अब", "कुछ", "तक", "लोगों", "का", "कोई", "इनमें"
]

# Define the Hindi text for processing
text_for_processing = """
2010 में, नासा की ग्रह रक्षा टीम ने पृथ्वी के पास 1 किमी चौड़े 90 प्रतिशत क्षुद्रग्रहों की पहचान की थी और उन्हें लॉग किया था। ये 'पृथ्वी के निकट की वस्तुएं' या NEO, पहाड़ों के आकार की हैं और इनमें पृथ्वी की कक्षा के 50 मिलियन किलोमीटर के भीतर की कोई भी चीज़ शामिल है। लॉग इन करने के लिए अनुमानित 50 शेष होने पर, नासा का कहना है कि जिन 887 के बारे में वह जानता है उनमें से कोई भी ग्रह के लिए महत्वपूर्ण खतरा नहीं है।
अब नासा कुछ छोटे क्षुद्रग्रहों को लॉग करने की दिशा में काम कर रहा है, जिनकी चौड़ाई 140 मीटर या उससे अधिक है। इस आकार के 25,000 अनुमानित क्षुद्रग्रहों में से, अब तक लगभग 8,000 को लॉग किया जा चुका है, 17,000 को छोड़ दिया गया है। यह देखते हुए कि 2013 में रूस के चेल्याबिंस्क शहर के ऊपर 19 मीटर के क्षुद्रग्रह में विस्फोट हुआ था, जिसमें 1,200 लोग घायल हो गए थे, ये मध्यम आकार के क्षुद्रग्रह यदि पृथ्वी की कक्षा में प्रवेश करते हैं तो एक गंभीर खतरा होंगे।
"""

# Tokenization using Indic NLP for Hindi
tokens = indic_tokenize.trivial_tokenize(text_for_processing, lang='hi')
print("Tokens:", tokens)

# Stanza Pipeline for Hindi
nlp_hindi = stanza.Pipeline('hi')
doc = nlp_hindi(text_for_processing)
lemmas = [word.lemma for sent in doc.sentences for word in sent.words]
print("Lemmas:", lemmas)

# Filter out custom stopwords
filtered_tokens = [token for token in tokens if token not in custom_hindi_stopwords]
print("Filtered Tokens:", filtered_tokens)
# Out:
# Collecting indic-nlp-library
#   Downloading indic_nlp_library-0.92-py3-none-any.whl.metadata (5.7 kB)
# Collecting sphinx-argparse (from indic-nlp-library)
#   Downloading sphinx_argparse-0.5.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting sphinx-rtd-theme (from indic-nlp-library)
#   Downloading sphinx_rtd_theme-3.0.1-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting morfessor (from indic-nlp-library)
#   Downloading Morfessor-2.0.6-py3-none-any.whl.metadata (628 bytes)
# Requirement already satisfied: pandas in c:\users\91636\anaconda3\lib\site-packages (from indic-nlp-library) (2.1.4)
# Requirement already satisfied: numpy in c:\users\91636\anaconda3\lib\site-packages (from indic-nlp-library) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\91636\appdata\roaming\python\python311\site-packages (from pandas->indic-nlp-library) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\91636\anaconda3\lib\site-packages (from pandas->indic-nlp-library) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\91636\anaconda3\lib\site-packages (from pandas->indic-nlp-library) (2023.3)
# Collecting sphinx>=5.1.0 (from sphinx-argparse->indic-nlp-library)
#   Downloading sphinx-8.1.3-py3-none-any.whl.metadata (6.4 kB)
# Collecting docutils>=0.19 (from sphinx-argparse->indic-nlp-library)
#   Downloading docutils-0.21.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting sphinxcontrib-jquery<5,>=4 (from sphinx-rtd-theme->indic-nlp-library)
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in c:\users\91636\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library) (1.16.0)
# Collecting sphinxcontrib-applehelp>=1.0.7 (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library)
#   Downloading sphinxcontrib_applehelp-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-devhelp>=1.0.6 (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library)
#   Downloading sphinxcontrib_devhelp-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-htmlhelp>=2.0.6 (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library)
#   Downloading sphinxcontrib_htmlhelp-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in c:\users\91636\anaconda3\lib\site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Collecting sphinxcontrib-qthelp>=1.0.6 (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library)
#   Downloading sphinxcontrib_qthelp-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-serializinghtml>=1.1.9 (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library)
#   Downloading sphinxcontrib_serializinghtml-2.0.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: Jinja2>=3.1 in c:\users\91636\anaconda3\lib\site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.3)
# Requirement already satisfied: Pygments>=2.17 in c:\users\91636\appdata\roaming\python\python311\site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.17.2)
# Requirement already satisfied: snowballstemmer>=2.2 in c:\users\91636\anaconda3\lib\site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.2.0)
# Collecting babel>=2.13 (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library)
#   Downloading babel-2.16.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting alabaster>=0.7.14 (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library)
#   Downloading alabaster-1.0.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: imagesize>=1.3 in c:\users\91636\anaconda3\lib\site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: requests>=2.30.0 in c:\users\91636\anaconda3\lib\site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.31.0)
# Requirement already satisfied: packaging>=23.0 in c:\users\91636\anaconda3\lib\site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (23.1)
# Requirement already satisfied: colorama>=0.4.6 in c:\users\91636\appdata\roaming\python\python311\site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\91636\anaconda3\lib\site-packages (from Jinja2>=3.1->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\91636\anaconda3\lib\site-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\91636\anaconda3\lib\site-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\91636\anaconda3\lib\site-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91636\anaconda3\lib\site-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2024.2.2)
# Downloading indic_nlp_library-0.92-py3-none-any.whl (40 kB)
#    ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#    ---------------------------------------- 40.3/40.3 kB 1.9 MB/s eta 0:00:00
# Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Downloading sphinx_argparse-0.5.2-py3-none-any.whl (12 kB)
# Downloading sphinx_rtd_theme-3.0.1-py2.py3-none-any.whl (7.7 MB)
#    ---------------------------------------- 0.0/7.7 MB ? eta -:--:--
#    ---------------------------------------- 0.1/7.7 MB 3.4 MB/s eta 0:00:03
#    - -------------------------------------- 0.2/7.7 MB 2.9 MB/s eta 0:00:03
#    - -------------------------------------- 0.4/7.7 MB 2.9 MB/s eta 0:00:03
#    -- ------------------------------------- 0.5/7.7 MB 2.9 MB/s eta 0:00:03
#    --- ------------------------------------ 0.6/7.7 MB 3.1 MB/s eta 0:00:03
#    --- ------------------------------------ 0.7/7.7 MB 2.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.0/7.7 MB 3.1 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.1/7.7 MB 3.1 MB/s eta 0:00:03
#    ------- -------------------------------- 1.4/7.7 MB 3.5 MB/s eta 0:00:02
#    -------- ------------------------------- 1.6/7.7 MB 3.5 MB/s eta 0:00:02
#    --------- ------------------------------ 1.8/7.7 MB 3.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.0/7.7 MB 3.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.2/7.7 MB 3.7 MB/s eta 0:00:02
#    ------------ --------------------------- 2.4/7.7 MB 3.8 MB/s eta 0:00:02
#    ------------- -------------------------- 2.5/7.7 MB 3.7 MB/s eta 0:00:02
#    -------------- ------------------------- 2.8/7.7 MB 3.8 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/7.7 MB 4.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.3/7.7 MB 4.0 MB/s eta 0:00:02
#    ------------------ --------------------- 3.5/7.7 MB 4.0 MB/s eta 0:00:02
#    ------------------- -------------------- 3.7/7.7 MB 4.0 MB/s eta 0:00:01
#    -------------------- ------------------- 3.9/7.7 MB 4.1 MB/s eta 0:00:01
#    --------------------- ------------------ 4.2/7.7 MB 4.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.4/7.7 MB 4.2 MB/s eta 0:00:01
#    ------------------------ --------------- 4.7/7.7 MB 4.3 MB/s eta 0:00:01
#    ------------------------ --------------- 4.8/7.7 MB 4.2 MB/s eta 0:00:01
#    -------------------------- ------------- 5.1/7.7 MB 4.3 MB/s eta 0:00:01
#    --------------------------- ------------ 5.3/7.7 MB 4.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.5/7.7 MB 4.3 MB/s eta 0:00:01
#    ------------------------------ --------- 5.7/7.7 MB 4.3 MB/s eta 0:00:01
#    ------------------------------- -------- 6.0/7.7 MB 4.4 MB/s eta 0:00:01
#    -------------------------------- ------- 6.2/7.7 MB 4.4 MB/s eta 0:00:01
#    -------------------------------- ------- 6.3/7.7 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.6/7.7 MB 4.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.8/7.7 MB 4.4 MB/s eta 0:00:01
#    ------------------------------------- -- 7.1/7.7 MB 4.4 MB/s eta 0:00:01
#    ------------------------------------- -- 7.2/7.7 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.7 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.7 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.7 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 7.7/7.7 MB 4.2 MB/s eta 0:00:00
# Downloading docutils-0.21.2-py3-none-any.whl (587 kB)
#    ---------------------------------------- 0.0/587.4 kB ? eta -:--:--
#    ------------- -------------------------- 204.8/587.4 kB 6.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 337.9/587.4 kB 5.2 MB/s eta 0:00:01
#    -------------------------------------- - 563.2/587.4 kB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 587.4/587.4 kB 3.7 MB/s eta 0:00:00
# Downloading sphinx-8.1.3-py3-none-any.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    - -------------------------------------- 0.2/3.5 MB 3.3 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.4/3.5 MB 3.2 MB/s eta 0:00:01
#    ------ --------------------------------- 0.6/3.5 MB 3.9 MB/s eta 0:00:01
#    ------- -------------------------------- 0.7/3.5 MB 3.9 MB/s eta 0:00:01
#    -------- ------------------------------- 0.7/3.5 MB 3.2 MB/s eta 0:00:01
#    ------------ --------------------------- 1.1/3.5 MB 3.7 MB/s eta 0:00:01
#    ------------- -------------------------- 1.2/3.5 MB 3.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.4/3.5 MB 3.8 MB/s eta 0:00:01
#    ------------------ --------------------- 1.6/3.5 MB 3.8 MB/s eta 0:00:01
#    -------------------- ------------------- 1.8/3.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.9/3.5 MB 4.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.1/3.5 MB 3.7 MB/s eta 0:00:01
#    -------------------------- ------------- 2.3/3.5 MB 3.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.5/3.5 MB 3.7 MB/s eta 0:00:01
#    ------------------------------- -------- 2.7/3.5 MB 3.9 MB/s eta 0:00:01
#    --------------------------------- ------ 2.9/3.5 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 3.2/3.5 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 3.3/3.5 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  3.5/3.5 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 3.8 MB/s eta 0:00:00
# Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.1 kB ? eta -:--:--
#    ------------------------------------- -- 112.6/121.1 kB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 121.1/121.1 kB 2.4 MB/s eta 0:00:00
# Downloading alabaster-1.0.0-py3-none-any.whl (13 kB)
# Downloading babel-2.16.0-py3-none-any.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#     --------------------------------------- 0.2/9.6 MB 4.6 MB/s eta 0:00:03
#    - -------------------------------------- 0.4/9.6 MB 4.1 MB/s eta 0:00:03
#    -- ------------------------------------- 0.6/9.6 MB 4.4 MB/s eta 0:00:03
#    --- ------------------------------------ 0.8/9.6 MB 4.6 MB/s eta 0:00:02
#    --- ------------------------------------ 0.9/9.6 MB 3.9 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.1/9.6 MB 4.1 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.2/9.6 MB 3.6 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.4/9.6 MB 3.8 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.6 MB 3.8 MB/s eta 0:00:03
#    ------- -------------------------------- 1.8/9.6 MB 3.8 MB/s eta 0:00:03
#    ------- -------------------------------- 1.9/9.6 MB 3.8 MB/s eta 0:00:03
#    -------- ------------------------------- 2.1/9.6 MB 3.6 MB/s eta 0:00:03
#    --------- ------------------------------ 2.3/9.6 MB 3.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.5/9.6 MB 3.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.7/9.6 MB 3.9 MB/s eta 0:00:02
#    ------------ --------------------------- 2.9/9.6 MB 3.9 MB/s eta 0:00:02
#    ------------- -------------------------- 3.1/9.6 MB 3.9 MB/s eta 0:00:02
#    ------------- -------------------------- 3.2/9.6 MB 3.8 MB/s eta 0:00:02
#    -------------- ------------------------- 3.5/9.6 MB 3.9 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.6 MB 3.9 MB/s eta 0:00:02
#    --------------- ------------------------ 3.8/9.6 MB 3.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.0/9.6 MB 3.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.6 MB 3.9 MB/s eta 0:00:02
#    ------------------ --------------------- 4.5/9.6 MB 4.0 MB/s eta 0:00:02
#    ------------------- -------------------- 4.6/9.6 MB 4.0 MB/s eta 0:00:02
#    -------------------- ------------------- 4.9/9.6 MB 4.1 MB/s eta 0:00:02
#    --------------------- ------------------ 5.1/9.6 MB 4.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.4/9.6 MB 4.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.5/9.6 MB 4.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.7/9.6 MB 4.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.7/9.6 MB 4.0 MB/s eta 0:00:01
#    ------------------------ --------------- 5.9/9.6 MB 3.9 MB/s eta 0:00:01
#    ------------------------- -------------- 6.1/9.6 MB 4.0 MB/s eta 0:00:01
#    -------------------------- ------------- 6.4/9.6 MB 4.0 MB/s eta 0:00:01
#    --------------------------- ------------ 6.5/9.6 MB 4.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.7/9.6 MB 4.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.0/9.6 MB 4.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.1/9.6 MB 4.0 MB/s eta 0:00:01
#    ------------------------------ --------- 7.4/9.6 MB 4.1 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.6 MB 4.1 MB/s eta 0:00:01
#    -------------------------------- ------- 7.9/9.6 MB 4.1 MB/s eta 0:00:01
#    --------------------------------- ------ 8.1/9.6 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.3/9.6 MB 4.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.4/9.6 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------ --- 8.7/9.6 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------ --- 8.8/9.6 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------- -- 9.0/9.6 MB 4.2 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.6 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.6 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  9.6/9.6 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  9.6/9.6 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 4.0 MB/s eta 0:00:00
# Downloading sphinxcontrib_applehelp-2.0.0-py3-none-any.whl (119 kB)
#    ---------------------------------------- 0.0/119.3 kB ? eta -:--:--
#    ---------------------------------------- 119.3/119.3 kB 3.5 MB/s eta 0:00:00
# Downloading sphinxcontrib_devhelp-2.0.0-py3-none-any.whl (82 kB)
#    ---------------------------------------- 0.0/82.5 kB ? eta -:--:--
#    ---------------------------------------- 82.5/82.5 kB 2.3 MB/s eta 0:00:00
# Downloading sphinxcontrib_htmlhelp-2.1.0-py3-none-any.whl (98 kB)
#    ---------------------------------------- 0.0/98.7 kB ? eta -:--:--
#    ------------------------------------- -- 92.2/98.7 kB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 98.7/98.7 kB 1.9 MB/s eta 0:00:00
# Downloading sphinxcontrib_qthelp-2.0.0-py3-none-any.whl (88 kB)
#    ---------------------------------------- 0.0/88.7 kB ? eta -:--:--
#    ---------------------------------------- 88.7/88.7 kB 4.9 MB/s eta 0:00:00
# Downloading sphinxcontrib_serializinghtml-2.0.0-py3-none-any.whl (92 kB)
#    ---------------------------------------- 0.0/92.1 kB ? eta -:--:--
#    ---------------------------------------- 92.1/92.1 kB 5.5 MB/s eta 0:00:00
# Installing collected packages: morfessor, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, docutils, babel, alabaster, sphinx, sphinxcontrib-jquery, sphinx-argparse, sphinx-rtd-theme, indic-nlp-library
#   Attempting uninstall: sphinxcontrib-serializinghtml
#     Found existing installation: sphinxcontrib-serializinghtml 1.1.5
#     Uninstalling sphinxcontrib-serializinghtml-1.1.5:
#       Successfully uninstalled sphinxcontrib-serializinghtml-1.1.5
#   Attempting uninstall: sphinxcontrib-qthelp
#     Found existing installation: sphinxcontrib-qthelp 1.0.3
#     Uninstalling sphinxcontrib-qthelp-1.0.3:
#       Successfully uninstalled sphinxcontrib-qthelp-1.0.3
#   Attempting uninstall: sphinxcontrib-htmlhelp
#     Found existing installation: sphinxcontrib-htmlhelp 2.0.0
#     Uninstalling sphinxcontrib-htmlhelp-2.0.0:
#       Successfully uninstalled sphinxcontrib-htmlhelp-2.0.0
#   Attempting uninstall: sphinxcontrib-devhelp
#     Found existing installation: sphinxcontrib-devhelp 1.0.2
#     Uninstalling sphinxcontrib-devhelp-1.0.2:
#       Successfully uninstalled sphinxcontrib-devhelp-1.0.2
#   Attempting uninstall: sphinxcontrib-applehelp
#     Found existing installation: sphinxcontrib-applehelp 1.0.2
#     Uninstalling sphinxcontrib-applehelp-1.0.2:
#       Successfully uninstalled sphinxcontrib-applehelp-1.0.2
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.18.1
#     Uninstalling docutils-0.18.1:
#       Successfully uninstalled docutils-0.18.1
#   Attempting uninstall: babel
#     Found existing installation: Babel 2.11.0
#     Uninstalling Babel-2.11.0:
#       Successfully uninstalled Babel-2.11.0
#   Attempting uninstall: alabaster
#     Found existing installation: alabaster 0.7.12
#     Uninstalling alabaster-0.7.12:
#       Successfully uninstalled alabaster-0.7.12
#   Attempting uninstall: sphinx
#     Found existing installation: Sphinx 5.0.2
#     Uninstalling Sphinx-5.0.2:
#       Successfully uninstalled Sphinx-5.0.2
# Successfully installed alabaster-1.0.0 babel-2.16.0 docutils-0.21.2 indic-nlp-library-0.92 morfessor-2.0.6 sphinx-8.1.3 sphinx-argparse-0.5.2 sphinx-rtd-theme-3.0.1 sphinxcontrib-applehelp-2.0.0 sphinxcontrib-devhelp-2.0.0 sphinxcontrib-htmlhelp-2.1.0 sphinxcontrib-jquery-4.1 sphinxcontrib-qthelp-2.0.0 sphinxcontrib-serializinghtml-2.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.4.3 requires jedi<0.19.0,>=0.17.2, but you have jedi 0.19.1 which is incompatible.
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: stanza in c:\users\91636\anaconda3\lib\site-packages (1.9.2)
# Requirement already satisfied: emoji in c:\users\91636\anaconda3\lib\site-packages (from stanza) (2.14.0)
# Requirement already satisfied: numpy in c:\users\91636\anaconda3\lib\site-packages (from stanza) (1.26.4)
# Requirement already satisfied: protobuf>=3.15.0 in c:\users\91636\anaconda3\lib\site-packages (from stanza) (3.20.3)
# Requirement already satisfied: requests in c:\users\91636\anaconda3\lib\site-packages (from stanza) (2.31.0)
# Requirement already satisfied: networkx in c:\users\91636\anaconda3\lib\site-packages (from stanza) (3.1)
# Requirement already satisfied: torch>=1.3.0 in c:\users\91636\anaconda3\lib\site-packages (from stanza) (2.5.1)
# Requirement already satisfied: tqdm in c:\users\91636\anaconda3\lib\site-packages (from stanza) (4.65.0)
# Requirement already satisfied: filelock in c:\users\91636\anaconda3\lib\site-packages (from torch>=1.3.0->stanza) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\91636\anaconda3\lib\site-packages (from torch>=1.3.0->stanza) (4.9.0)
# Requirement already satisfied: jinja2 in c:\users\91636\anaconda3\lib\site-packages (from torch>=1.3.0->stanza) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\91636\anaconda3\lib\site-packages (from torch>=1.3.0->stanza) (2023.10.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\91636\anaconda3\lib\site-packages (from torch>=1.3.0->stanza) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\91636\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.3.0->stanza) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\91636\anaconda3\lib\site-packages (from requests->stanza) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\91636\anaconda3\lib\site-packages (from requests->stanza) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\91636\anaconda3\lib\site-packages (from requests->stanza) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91636\anaconda3\lib\site-packages (from requests->stanza) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\91636\appdata\roaming\python\python311\site-packages (from tqdm->stanza) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\91636\anaconda3\lib\site-packages (from jinja2->torch>=1.3.0->stanza) (2.1.3)
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.9.0.json:   0%|   …
# 2024-11-05 23:51:11 INFO: Downloaded file to C:\Users\91636\stanza_resources\resources.json
# 2024-11-05 23:51:11 INFO: Downloading default packages for language: hi (Hindi) ...
# 2024-11-05 23:51:12 INFO: File exists: C:\Users\91636\stanza_resources\hi\default.zip
# 2024-11-05 23:51:16 INFO: Finished downloading models and saved to C:\Users\91636\stanza_resources
# 2024-11-05 23:51:16 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Tokens: ['\n2010', 'में', ',', 'नासा', 'की', 'ग्रह', 'रक्षा', 'टीम', 'ने', 'पृथ्वी', 'के', 'पास', '1', 'किमी', 'चौड़े', '90', 'प्रतिशत', 'क्षुद्रग्रहों', 'की', 'पहचान', 'की', 'थी', 'और', 'उन्हें', 'लॉग', 'किया', 'था', '।', 'ये', "'", 'पृथ्वी', 'के', 'निकट', 'की', 'वस्तुएं', "'", 'या', 'NEO', ',', 'पहाड़ों', 'के', 'आकार', 'की', 'हैं', 'और', 'इनमें', 'पृथ्वी', 'की', 'कक्षा', 'के', '50', 'मिलियन', 'किलोमीटर', 'के', 'भीतर', 'की', 'कोई', 'भी', 'चीज़', 'शामिल', 'है', '।', 'लॉग', 'इन', 'करने', 'के', 'लिए', 'अनुमानित', '50', 'शेष', 'होने', 'पर', ',', 'नासा', 'का', 'कहना', 'है', 'कि', 'जिन', '887', 'के', 'बारे', 'में', 'वह', 'जानता', 'है', 'उनमें', 'से', 'कोई', 'भी', 'ग्रह', 'के', 'लिए', 'महत्वपूर्ण', 'खतरा', 'नहीं', 'है', '।', '\nअब', 'नासा', 'कुछ', 'छोटे', 'क्षुद्रग्रहों', 'को', 'लॉग', 'करने', 'की', 'दिशा', 'में', 'काम', 'कर', 'रहा', 'है', ',', 'जिनकी', 'चौड़ाई', '140', 'मीटर', 'या', 'उससे', 'अधिक', 'है', '।', 'इस', 'आकार', 'के', '25,000', 'अनुमानित', 'क्षुद्रग्रहों', 'में', 'से', ',', 'अब', 'तक', 'लगभग', '8,000', 'को', 'लॉग', 'किया', 'जा', 'चुका', 'है', ',', '17,000', 'को', 'छोड़', 'दिया', 'गया', 'है', '।', 'यह', 'देखते', 'हुए', 'कि', '2013', 'में', 'रूस', 'के', 'चेल्याबिंस्क', 'शहर', 'के', 'ऊपर', '19', 'मीटर', 'के', 'क्षुद्रग्रह', 'में', 'विस्फोट', 'हुआ', 'था', ',', 'जिसमें', '1,200', 'लोग', 'घायल', 'हो', 'गए', 'थे', ',', 'ये', 'मध्यम', 'आकार', 'के', 'क्षुद्रग्रह', 'यदि', 'पृथ्वी', 'की', 'कक्षा', 'में', 'प्रवेश', 'करते', 'हैं', 'तो', 'एक', 'गंभीर', 'खतरा', 'होंगे', '।', '\n']
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.9.0.json:   0%|   …
# 2024-11-05 23:51:17 INFO: Downloaded file to C:\Users\91636\stanza_resources\resources.json
# 2024-11-05 23:51:18 INFO: Loading these models for language: hi (Hindi):
# =============================
# | Processor | Package       |
# -----------------------------
# | tokenize  | hdtb          |
# | pos       | hdtb_charlm   |
# | lemma     | hdtb_nocharlm |
# | depparse  | hdtb_charlm   |
# =============================
#
# 2024-11-05 23:51:18 INFO: Using device: cpu
# 2024-11-05 23:51:18 INFO: Loading: tokenize
# c:\Users\91636\anaconda3\Lib\site-packages\stanza\models\tokenization\trainer.py:82: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2024-11-05 23:51:21 INFO: Loading: pos
# c:\Users\91636\anaconda3\Lib\site-packages\stanza\models\pos\trainer.py:139: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# c:\Users\91636\anaconda3\Lib\site-packages\stanza\models\common\pretrain.py:56: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(self.filename, lambda storage, loc: storage)
# c:\Users\91636\anaconda3\Lib\site-packages\stanza\models\common\char_model.py:271: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(filename, lambda storage, loc: storage)
# 2024-11-05 23:51:21 INFO: Loading: lemma
# c:\Users\91636\anaconda3\Lib\site-packages\stanza\models\lemma\trainer.py:239: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2024-11-05 23:51:21 INFO: Loading: depparse
# c:\Users\91636\anaconda3\Lib\site-packages\stanza\models\depparse\trainer.py:194: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2024-11-05 23:51:22 INFO: Done loading processors!
# Lemmas: ['2010', 'में', ',', 'नासा', 'का', 'ग्रह', 'रक्षा', 'टीम', 'ने', 'पृथ्वी', 'का', 'पास', '1', 'किमी', 'चौड़ा', '90', 'प्रतिशत', 'क्षुद्रग्रह', 'का', 'पहचान', 'करना', 'था', 'और', 'वह', 'लॉग', 'करना', 'था', '।', 'यह', "'", 'पृथ्वी', 'का', 'निकट', 'का', 'वस्तु', "'", 'या', 'NEO', ',', 'पहाड', 'का', 'आकार', 'का', 'है', 'और', 'यह', 'पृथ्वी', 'का', 'कक्षा', 'का', '50', 'मिलियन', 'किलोमीटर', 'का', 'भीतर', 'का', 'कोई', 'भी', 'चीज़', 'शामिल', 'है', '।', 'लॉग', 'यह', 'करना', 'का', 'लिए', 'अनुमानित', '50', 'शेष', 'होना', 'पर', ',', 'नासा', 'का', 'कहना', 'है', 'कि', 'जो', '887', 'का', 'बारे', 'में', 'वह', 'जानना', 'है', 'वह', 'से', 'कोई', 'भी', 'ग्रह', 'का', 'लिए', 'महत्वपूर्ण', 'खतरा', 'नहीं', 'है', '।', 'अब', 'नासा', 'कुछ', 'छोटा', 'क्षुद्रग्रह', 'को', 'लॉग', 'करना', 'का', 'दिशा', 'में', 'काम', 'करना', 'रहना', 'है', ',', 'जो', 'चौड़ाई', '140', 'मीटर', 'या', 'वह', 'अधिक', 'है', '।', 'यह', 'आकार', 'का', '25000', 'अनुमानित', 'क्षुद्रग्रह', 'में', 'से', ',', 'अब', 'तक', 'लगभग', '8000', 'को', 'लॉग', 'करना', 'जाना', 'चुकना', 'है', ',', '17000', 'को', 'छोड़ना', 'देना', 'जाना', 'है', '।', 'यह', 'देखना', 'होना', 'कि', '2013', 'में', 'रूस', 'का', 'चेल्याबिंस्क', 'शहर', 'का', 'ऊपर', '19', 'मीटर', 'का', 'क्षुद्रग्रह', 'में', 'विस्फोट', 'होना', 'था', ',', 'जो', '1200', 'लोग', 'घायल', 'होना', 'जाना', 'था', ',', 'यह', 'मध्यम', 'आकार', 'का', 'क्षुद्रग्रह', 'यदि', 'पृथ्वी', 'का', 'कक्षा', 'में', 'प्रवेश', 'करना', 'है', 'तो', 'एक', 'गंभीर', 'खतरा', 'होना', '।']
# Filtered Tokens: ['\n2010', ',', 'नासा', 'ग्रह', 'रक्षा', 'टीम', 'पृथ्वी', 'पास', '1', 'किमी', 'चौड़े', '90', 'प्रतिशत', 'क्षुद्रग्रहों', 'पहचान', 'थी', 'उन्हें', 'लॉग', 'किया', 'था', '।', 'ये', "'", 'पृथ्वी', 'निकट', 'वस्तुएं', "'", 'या', 'NEO', ',', 'पहाड़ों', 'आकार', 'पृथ्वी', 'कक्षा', '50', 'मिलियन', 'किलोमीटर', 'भीतर', 'भी', 'चीज़', 'शामिल', '।', 'लॉग', 'इन', 'करने', 'लिए', 'अनुमानित', '50', 'शेष', 'होने', ',', 'नासा', 'कहना', 'कि', '887', 'बारे', 'वह', 'जानता', 'उनमें', 'भी', 'ग्रह', 'लिए', 'महत्वपूर्ण', 'खतरा', 'नहीं', '।', '\nअब', 'नासा', 'छोटे', 'क्षुद्रग्रहों', 'लॉग', 'करने', 'दिशा', 'काम', 'कर', 'रहा', ',', 'जिनकी', 'चौड़ाई', '140', 'मीटर', 'या', 'उससे', 'अधिक', '।', 'इस', 'आकार', '25,000', 'अनुमानित', 'क्षुद्रग्रहों', ',', 'लगभग', '8,000', 'लॉग', 'किया', 'जा', 'चुका', ',', '17,000', 'छोड़', 'दिया', 'गया', '।', 'देखते', 'हुए', 'कि', '2013', 'रूस', 'चेल्याबिंस्क', 'शहर', 'ऊपर', '19', 'मीटर', 'क्षुद्रग्रह', 'विस्फोट', 'हुआ', 'था', ',', '1,200', 'लोग', 'घायल', 'हो', 'गए', 'थे', ',', 'ये', 'मध्यम', 'आकार', 'क्षुद्रग्रह', 'पृथ्वी', 'कक्षा', 'प्रवेश', 'करते', 'तो', 'एक', 'गंभीर', 'खतरा', 'होंगे', '।', '\n']

# %%
# Import necessary libraries
from indicnlp.tokenize import indic_tokenize
import stanza
from nltk import Tree
from nltk.stem import SnowballStemmer

# Download necessary resources
stanza.download('hi')

# Define the Hindi text
text_for_processing = """
2010 में, नासा की ग्रह रक्षा टीम ने पृथ्वी के पास 1 किमी चौड़े 90 प्रतिशत क्षुद्रग्रहों की पहचान की थी और उन्हें लॉग किया था। ये 'पृथ्वी के निकट की वस्तुएं' या NEO, पहाड़ों के आकार की हैं और इनमें पृथ्वी की कक्षा के 50 मिलियन किलोमीटर के भीतर की कोई भी चीज़ शामिल है। लॉग इन करने के लिए अनुमानित 50 शेष होने पर, नासा का कहना है कि जिन 887 के बारे में वह जानता है उनमें से कोई भी ग्रह के लिए महत्वपूर्ण खतरा नहीं है।
अब नासा कुछ छोटे क्षुद्रग्रहों को लॉग करने की दिशा में काम कर रहा है, जिनकी चौड़ाई 140 मीटर या उससे अधिक है। इस आकार के 25,000 अनुमानित क्षुद्रग्रहों में से, अब तक लगभग 8,000 को लॉग किया जा चुका है, 17,000 को छोड़ दिया गया है। यह देखते हुए कि 2013 में रूस के चेल्याबिंस्क शहर के ऊपर 19 मीटर के क्षुद्रग्रह में विस्फोट हुआ था, जिसमें 1,200 लोग घायल हो गए थे, ये मध्यम आकार के क्षुद्रग्रह यदि पृथ्वी की कक्षा में प्रवेश करते हैं तो एक गंभीर खतरा होंगे।
"""

# Initialize Stanza Pipeline for Hindi
nlp_hindi = stanza.Pipeline('hi')

# Process the text using Stanza
doc = nlp_hindi(text_for_processing)

# 1. Morphological Analysis
print("Morphological Analysis:")
for sentence in doc.sentences:
    for word in sentence.words:
        print(f"Word: {word.text}, Lemma: {word.lemma}, POS: {word.pos}, Morphology: {word.feats}")

# 2. POS Tagging (Rule-Based)
print("\nPOS Tagging (Stanza + Rule-Based):")
for sentence in doc.sentences:
    for word in sentence.words:
        pos_tag = word.pos
        # Basic rule-based adjustments if needed
        if word.text in ["हैं", "है"]:  # Example rule: recognize "हैं" and "है" as auxiliary verbs
            pos_tag = "AUX"
        print(f"Word: {word.text}, POS Tag: {pos_tag}")

# 3. Chunking (Noun and Verb Phrases)
print("\nChunking (Noun and Verb Phrases):")
chunked_sentences = []
for sentence in doc.sentences:
    chunked_sentence = []
    current_chunk = []
    for word in sentence.words:
        if word.pos in ["NOUN", "PROPN"]:  # Noun Phrase
            current_chunk.append(word.text)
        elif current_chunk:
            chunked_sentence.append(("NP", " ".join(current_chunk)))
            current_chunk = []
        if word.pos in ["VERB", "AUX"]:  # Verb Phrase
            chunked_sentence.append(("VP", word.text))
    if current_chunk:  # Append any remaining noun phrase
        chunked_sentence.append(("NP", " ".join(current_chunk)))
    chunked_sentences.append(chunked_sentence)

# Display chunked sentences
for i, chunks in enumerate(chunked_sentences):
    print(f"Sentence {i+1} Chunks:")
    for chunk_type, chunk_text in chunks:
        print(f"  {chunk_type}: {chunk_text}")

# 4. Named Entity Recognition (NER)
import re

# Predefined lists of known entities specific to the text
KNOWN_LOCATIONS = ["पृथ्वी", "चेल्याबिंस्क", "रूस"]
KNOWN_ORGANIZATIONS = ["नासा"]
KNOWN_ENTITY_TYPES = ["क्षुद्रग्रह", "ग्रह", "कक्षा", "वस्तुएं"]


# Rule-based NER function
def rule_based_ner(text_for_processing):
    entities = []

    # Match predefined locations
    for location in KNOWN_LOCATIONS:
        if location in text_for_processing:
            entities.append({
                'entity': location,
                'type': 'LOCATION'
            })

    # Match predefined organizations
    for org in KNOWN_ORGANIZATIONS:
        if org in text_for_processing:
            entities.append({
                'entity': org,
                'type': 'ORGANIZATION'
            })

    # Match other domain-specific entity types
    for entity_type in KNOWN_ENTITY_TYPES:
        if entity_type in text_for_processing:
            entities.append({
                'entity': entity_type,
                'type': 'DOMAIN_ENTITY'
            })

    # Regex pattern for detecting years and large numbers (e.g., 2010, 50 million, 25,000)
    years = re.findall(r'\b\d{4}\b', text_for_processing)
    for year in years:
        entities.append({
            'entity': year,
            'type': 'DATE'
        })

    # Regex for large numbers (used in astronomy context, such as distances or quantities)
    large_numbers = re.findall(r'\b\d{1,3}(?:,\d{3})*\b', text_for_processing)
    for number in large_numbers:
        entities.append({
            'entity': number,
            'type': 'QUANTITY'
        })

    return entities

# Perform rule-based NER
ner_results = rule_based_ner(text_for_processing)

# Print recognized entities
print("Recognized Entities:")
for entity in ner_results:
    print(f"Entity: {entity['entity']}, Type: {entity['type']}")
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.9.0.json:   0%|   …
# 2024-11-05 23:52:37 INFO: Downloaded file to C:\Users\91636\stanza_resources\resources.json
# 2024-11-05 23:52:37 INFO: Downloading default packages for language: hi (Hindi) ...
# 2024-11-05 23:52:38 INFO: File exists: C:\Users\91636\stanza_resources\hi\default.zip
# 2024-11-05 23:52:42 INFO: Finished downloading models and saved to C:\Users\91636\stanza_resources
# 2024-11-05 23:52:42 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.9.0.json:   0%|   …
# 2024-11-05 23:52:43 INFO: Downloaded file to C:\Users\91636\stanza_resources\resources.json
# 2024-11-05 23:52:44 INFO: Loading these models for language: hi (Hindi):
# =============================
# | Processor | Package       |
# -----------------------------
# | tokenize  | hdtb          |
# | pos       | hdtb_charlm   |
# | lemma     | hdtb_nocharlm |
# | depparse  | hdtb_charlm   |
# =============================
#
# 2024-11-05 23:52:44 INFO: Using device: cpu
# 2024-11-05 23:52:44 INFO: Loading: tokenize
# 2024-11-05 23:52:44 INFO: Loading: pos
# 2024-11-05 23:52:45 INFO: Loading: lemma
# 2024-11-05 23:52:45 INFO: Loading: depparse
# 2024-11-05 23:52:46 INFO: Done loading processors!
# Morphological Analysis:
# Word: 2010, Lemma: 2010, POS: PROPN, Morphology: Case=Acc|Gender=Masc|Number=Sing|Person=3
# Word: में, Lemma: में, POS: ADP, Morphology: AdpType=Post
# Word: ,, Lemma: ,, POS: PUNCT, Morphology: None
# Word: नासा, Lemma: नासा, POS: PROPN, Morphology: Case=Acc|Gender=Masc|Number=Sing|Person=3
# Word: की, Lemma: का, POS: ADP, Morphology: AdpType=Post|Case=Acc|Gender=Fem|Number=Sing
# Word: ग्रह, Lemma: ग्रह, POS: PROPN, Morphology: Case=Nom|Gender=Masc|Number=Sing|Person=3
# Word: रक्षा, Lemma: रक्षा, POS: PROPN, Morphology: Case=Nom|Gender=Fem|Number=Sing|Person=3
# Word: टीम, Lemma: टीम, POS: PROPN, Morphology: Case=Acc|Gender=Fem|Number=Sing|Person=3
# Word: ने, Lemma: ने, POS: ADP, Morphology: AdpType=Post
# Word: पृथ्वी, Lemma: पृथ्वी, POS: PROPN, Morphology: Case=Acc|Gender=Fem|Number=Sing|Person=3
# Word: के, Lemma: का, POS: ADP, Morphology: AdpType=Post
# Word: पास, Lemma: पास, POS: ADP, Morphology: AdpType=Post|Case=Nom|Gender=Masc|Number=Sing|Person=3
# Word: 1, Lemma: 1, POS: NUM, Morphology: NumType=Card
# Word: किमी, Lemma: किमी, POS: NOUN, Morphology: Case=Nom|Gender=Masc|Number=Sing|Person=3
# Word: चौड़े, Lemma: चौड़ा, POS: ADJ, Morphology: Case=Acc|Gender=Masc|Number=Plur
# Word: 90, Lemma: 90, POS: NUM, Morphology: NumType=Card
# Word: प्रतिशत, Lemma: प्रतिशत, POS: NOUN, Morphology: Case=Nom|Gender=Masc|Number=Sing|Person=3
# Word: क्षुद्रग्रहों, Lemma: क्षुद्रग्रह, POS: NOUN, Morphology: Case=Acc|Gender=Masc|Number=Plur|Person=3
# Word: की, Lemma: का, POS: ADP, Morphology: AdpType=Post|Case=Nom|Gender=Fem|Number=Sing
# Word: पहचान, Lemma: पहचान, POS: NOUN, Morphology: Case=Nom|Gender=Fem|Number=Sing|Person=3
# Word: की, Lemma: करना, POS: VERB, Morphology: Aspect=Perf|Gender=Fem|Number=Sing|VerbForm=Part|Voice=Act
# Word: थी, Lemma: था, POS: AUX, Morphology: Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin
# Word: और, Lemma: और, POS: CCONJ, Morphology: None
# Word: उन्हें, Lemma: वह, POS: PRON, Morphology: Case=Acc,Dat|Number=Sing|Person=3|Polite=Form|PronType=Prs
# Word: लॉग, Lemma: लॉग, POS: X, Morphology: Foreign=Yes
# Word: किया, Lemma: करना, POS: VERB, Morphology: Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part|Voice=Act
# Word: था, Lemma: था, POS: AUX, Morphology: Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin
# Word: ।, Lemma: ।, POS: PUNCT, Morphology: None
# Word: ये, Lemma: यह, POS: PRON, Morphology: Case=Nom|Number=Plur|Person=3|PronType=Prs
# Word: ', Lemma: ', POS: PUNCT, Morphology: None
# Word: पृथ्वी, Lemma: पृथ्वी, POS: NOUN, Morphology: Case=Acc|Gender=Fem|Number=Sing|Person=3
# Word: के, Lemma: का, POS: ADP, Morphology: AdpType=Post
# Word: निकट, Lemma: निकट, POS: ADP, Morphology: AdpType=Post|Case=Acc|Gender=Masc|Number=Sing|Person=3
# Word: की, Lemma: का, POS: ADP, Morphology: AdpType=Post|Case=Nom|Gender=Fem|Number=Plur
# Word: वस्तुएं, Lemma: वस्तु, POS: NOUN, Morphology: Case=Nom|Gender=Fem|Number=Plur|Person=3
# Word: ', Lemma: ', POS: PUNCT, Morphology: None
# Word: या, Lemma: या, POS: CCONJ, Morphology: None
# Word: NEO, Lemma: NEO, POS: PROPN, Morphology: Case=Acc|Gender=Masc|Number=Sing|Person=3
# Word: ,, Lemma: ,, POS: PUNCT, Morphology: None
# Word: पहाड़ों, Lemma: पहाड, POS: NOUN, Morphology: Case=Acc|Gender=Masc|Number=Plur|Person=3
# Word: के, Lemma: का, POS: ADP, Morphology: AdpType=Post|Case=Acc|Gender=Masc|Number=Sing
# Word: आकार, Lemma: आकार, POS: NOUN, Morphology: Case=Acc|Gender=Masc|Number=Sing|Person=3
# Word: की, Lemma: का, POS: ADP, Morphology: AdpType=Post|Case=Nom|Gender=Fem|Number=Plur
# Word: हैं, Lemma: है, POS: AUX, Morphology: Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# Word: और, Lemma: और, POS: CCONJ, Morphology: None
# Word: इनमें, Lemma: यह, POS: PRON, Morphology: Case=Acc,Ine|Number=Plur|Person=3|PronType=Prs
# Word: पृथ्वी, Lemma: पृथ्वी, POS: PROPN, Morphology: Case=Acc|Gender=Fem|Number=Sing|Person=3
# Word: की, Lemma: का, POS: ADP, Morphology: AdpType=Post|Case=Acc|Gender=Fem|Number=Sing
# Word: कक्षा, Lemma: कक्षा, POS: NOUN, Morphology: Case=Acc|Gender=Fem|Number=Sing|Person=3
# Word: के, Lemma: का, POS: ADP, Morphology: AdpType=Post|Case=Acc|Gender=Masc|Number=Plur
# Word: 50, Lemma: 50, POS: NUM, Morphology: NumType=Card
# Word: मिलियन, Lemma: मिलियन, POS: NUM, Morphology: NumType=Card
# Word: किलोमीटर, Lemma: किलोमीटर, POS: NOUN, Morphology: Case=Acc|Gender=Masc|Number=Sing|Person=3
# Word: के, Lemma: का, POS: ADP, Morphology: AdpType=Post
# Word: भीतर, Lemma: भीतर, POS: ADP, Morphology: AdpType=Post|Case=Acc|Gender=Masc|Number=Sing|Person=3
# Word: की, Lemma: का, POS: ADP, Morphology: AdpType=Post|Case=Nom|Gender=Fem|Number=Sing
# Word: कोई, Lemma: कोई, POS: PRON, Morphology: Case=Nom|Number=Sing|Person=3|PronType=Prs
# Word: भी, Lemma: भी, POS: PART, Morphology: None
# Word: चीज़, Lemma: चीज़, POS: NOUN, Morphology: Case=Nom|Gender=Fem|Number=Sing|Person=3
# Word: शामिल, Lemma: शामिल, POS: ADJ, Morphology: None
# Word: है, Lemma: है, POS: AUX, Morphology: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# Word: ।, Lemma: ।, POS: PUNCT, Morphology: None
# Word: लॉग, Lemma: लॉग, POS: NOUN, Morphology: Case=Nom|Gender=Masc|Number=Sing|Person=3
# Word: इन, Lemma: यह, POS: X, Morphology: Foreign=Yes
# Word: करने, Lemma: करना, POS: VERB, Morphology: Case=Acc|VerbForm=Inf
# Word: के, Lemma: का, POS: ADP, Morphology: AdpType=Post
# Word: लिए, Lemma: लिए, POS: ADP, Morphology: AdpType=Post
# Word: अनुमानित, Lemma: अनुमानित, POS: ADJ, Morphology: Case=Nom
# Word: 50, Lemma: 50, POS: NUM, Morphology: NumType=Card
# Word: शेष, Lemma: शेष, POS: ADJ, Morphology: None
# Word: होने, Lemma: होना, POS: VERB, Morphology: Case=Acc|VerbForm=Inf
# Word: पर, Lemma: पर, POS: ADP, Morphology: AdpType=Post
# Word: ,, Lemma: ,, POS: PUNCT, Morphology: None
# Word: नासा, Lemma: नासा, POS: PROPN, Morphology: Case=Acc|Gender=Masc|Number=Sing|Person=3
# Word: का, Lemma: का, POS: ADP, Morphology: AdpType=Post|Case=Nom|Gender=Masc|Number=Sing
# Word: कहना, Lemma: कहना, POS: VERB, Morphology: Case=Nom|VerbForm=Inf
# Word: है, Lemma: है, POS: VERB, Morphology: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# Word: कि, Lemma: कि, POS: SCONJ, Morphology: None
# Word: जिन, Lemma: जो, POS: DET, Morphology: Case=Acc|Number=Plur|Person=3|PronType=Dem
# Word: 887, Lemma: 887, POS: NUM, Morphology: Case=Acc|NumType=Card|Number=Plur
# Word: के, Lemma: का, POS: ADP, Morphology: AdpType=Post
# Word: बारे, Lemma: बारे, POS: ADP, Morphology: AdpType=Post
# Word: में, Lemma: में, POS: ADP, Morphology: AdpType=Post
# Word: वह, Lemma: वह, POS: PRON, Morphology: Case=Nom|Number=Sing|Person=3|PronType=Prs
# Word: जानता, Lemma: जानना, POS: VERB, Morphology: Aspect=Imp|Gender=Masc|Number=Sing|Person=3|VerbForm=Part|Voice=Act
# Word: है, Lemma: है, POS: AUX, Morphology: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Word: उनमें, Lemma: वह, POS: PRON, Morphology: Case=Acc,Ine|Number=Plur|Person=3|PronType=Prs
# Word: से, Lemma: से, POS: ADP, Morphology: AdpType=Post
# Word: कोई, Lemma: कोई, POS: PRON, Morphology: Case=Nom|Number=Sing|Person=3|PronType=Prs
# Word: भी, Lemma: भी, POS: PART, Morphology: None
# Word: ग्रह, Lemma: ग्रह, POS: NOUN, Morphology: Case=Acc|Gender=Masc|Number=Sing|Person=3
# Word: के, Lemma: का, POS: ADP, Morphology: AdpType=Post
# Word: लिए, Lemma: लिए, POS: ADP, Morphology: AdpType=Post
# Word: महत्वपूर्ण, Lemma: महत्वपूर्ण, POS: ADJ, Morphology: Case=Nom
# Word: खतरा, Lemma: खतरा, POS: NOUN, Morphology: Case=Nom|Gender=Masc|Number=Sing|Person=3
# Word: नहीं, Lemma: नहीं, POS: PART, Morphology: Polarity=Neg|PronType=Neg
# Word: है, Lemma: है, POS: AUX, Morphology: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# Word: ।, Lemma: ।, POS: PUNCT, Morphology: None
# Word: अब, Lemma: अब, POS: PRON, Morphology: Case=Nom|PronType=Prs
# Word: नासा, Lemma: नासा, POS: PROPN, Morphology: Case=Nom|Gender=Fem|Number=Sing|Person=3
# Word: कुछ, Lemma: कुछ, POS: DET, Morphology: PronType=Ind
# Word: छोटे, Lemma: छोटा, POS: ADJ, Morphology: Case=Acc|Gender=Masc|Number=Plur
# Word: क्षुद्रग्रहों, Lemma: क्षुद्रग्रह, POS: NOUN, Morphology: Case=Acc|Gender=Masc|Number=Plur|Person=3
# Word: को, Lemma: को, POS: ADP, Morphology: AdpType=Post
# Word: लॉग, Lemma: लॉग, POS: X, Morphology: Foreign=Yes
# Word: करने, Lemma: करना, POS: VERB, Morphology: Case=Acc|Number=Sing|VerbForm=Inf
# Word: की, Lemma: का, POS: ADP, Morphology: AdpType=Post|Case=Acc|Gender=Fem|Number=Sing
# Word: दिशा, Lemma: दिशा, POS: NOUN, Morphology: Case=Acc|Gender=Fem|Number=Sing|Person=3
# Word: में, Lemma: में, POS: ADP, Morphology: AdpType=Post
# Word: काम, Lemma: काम, POS: NOUN, Morphology: Case=Nom|Gender=Masc|Number=Sing|Person=3
# Word: कर, Lemma: करना, POS: VERB, Morphology: Gender=Masc|Number=Sing|Person=3|Voice=Act
# Word: रहा, Lemma: रहना, POS: AUX, Morphology: Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part
# Word: है, Lemma: है, POS: AUX, Morphology: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Word: ,, Lemma: ,, POS: PUNCT, Morphology: None
# Word: जिनकी, Lemma: जो, POS: PRON, Morphology: Case=Acc,Gen|Gender=Fem|Number=Plur|Person=3|Poss=Yes|PronType=Prs
# Word: चौड़ाई, Lemma: चौड़ाई, POS: NOUN, Morphology: Case=Nom|Gender=Fem|Number=Sing|Person=3
# Word: 140, Lemma: 140, POS: NUM, Morphology: NumType=Card
# Word: मीटर, Lemma: मीटर, POS: NOUN, Morphology: Case=Nom|Gender=Masc|Number=Sing|Person=3
# Word: या, Lemma: या, POS: CCONJ, Morphology: None
# Word: उससे, Lemma: वह, POS: PRON, Morphology: Case=Acc,Ins|Number=Sing|Person=3|PronType=Prs
# Word: अधिक, Lemma: अधिक, POS: DET, Morphology: PronType=Ind
# Word: है, Lemma: है, POS: AUX, Morphology: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# Word: ।, Lemma: ।, POS: PUNCT, Morphology: None
# Word: इस, Lemma: यह, POS: DET, Morphology: Case=Acc|Number=Sing|Person=3|PronType=Dem
# Word: आकार, Lemma: आकार, POS: NOUN, Morphology: Case=Acc|Gender=Masc|Number=Sing|Person=3
# Word: के, Lemma: का, POS: ADP, Morphology: AdpType=Post|Case=Acc|Gender=Masc|Number=Plur
# Word: 25,000, Lemma: 25000, POS: NUM, Morphology: NumType=Card
# Word: अनुमानित, Lemma: अनुमानित, POS: ADJ, Morphology: Case=Acc
# Word: क्षुद्रग्रहों, Lemma: क्षुद्रग्रह, POS: NOUN, Morphology: Case=Acc|Gender=Masc|Number=Plur|Person=3
# Word: में, Lemma: में, POS: ADP, Morphology: AdpType=Post
# Word: से, Lemma: से, POS: ADP, Morphology: AdpType=Post
# Word: ,, Lemma: ,, POS: PUNCT, Morphology: None
# Word: अब, Lemma: अब, POS: PRON, Morphology: Case=Acc|PronType=Prs
# Word: तक, Lemma: तक, POS: ADP, Morphology: AdpType=Post
# Word: लगभग, Lemma: लगभग, POS: PART, Morphology: None
# Word: 8,000, Lemma: 8000, POS: NUM, Morphology: Case=Acc|NumType=Card
# Word: को, Lemma: को, POS: ADP, Morphology: AdpType=Post
# Word: लॉग, Lemma: लॉग, POS: X, Morphology: Foreign=Yes
# Word: किया, Lemma: करना, POS: VERB, Morphology: Aspect=Perf|Gender=Masc|Number=Sing|Person=3|VerbForm=Part|Voice=Pass
# Word: जा, Lemma: जाना, POS: AUX, Morphology: None
# Word: चुका, Lemma: चुकना, POS: VERB, Morphology: Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part
# Word: है, Lemma: है, POS: AUX, Morphology: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Word: ,, Lemma: ,, POS: PUNCT, Morphology: None
# Word: 17,000, Lemma: 17000, POS: NUM, Morphology: Case=Acc|NumType=Card
# Word: को, Lemma: को, POS: ADP, Morphology: AdpType=Post
# Word: छोड़, Lemma: छोड़ना, POS: VERB, Morphology: Gender=Masc|Number=Sing|Person=3|Voice=Pass
# Word: दिया, Lemma: देना, POS: VERB, Morphology: Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part
# Word: गया, Lemma: जाना, POS: AUX, Morphology: Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part
# Word: है, Lemma: है, POS: AUX, Morphology: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Word: ।, Lemma: ।, POS: PUNCT, Morphology: None
# Word: यह, Lemma: यह, POS: PRON, Morphology: Case=Nom|Number=Sing|Person=3|PronType=Prs
# Word: देखते, Lemma: देखना, POS: VERB, Morphology: Aspect=Imp|Gender=Masc|Number=Sing|VerbForm=Part
# Word: हुए, Lemma: होना, POS: AUX, Morphology: Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part
# Word: कि, Lemma: कि, POS: SCONJ, Morphology: None
# Word: 2013, Lemma: 2013, POS: PROPN, Morphology: Case=Acc|Gender=Masc|Number=Sing|Person=3
# Word: में, Lemma: में, POS: ADP, Morphology: AdpType=Post
# Word: रूस, Lemma: रूस, POS: PROPN, Morphology: Case=Acc|Gender=Masc|Number=Sing|Person=3
# Word: के, Lemma: का, POS: ADP, Morphology: AdpType=Post|Case=Acc|Gender=Masc|Number=Sing
# Word: चेल्याबिंस्क, Lemma: चेल्याबिंस्क, POS: PROPN, Morphology: Case=Nom|Gender=Masc|Number=Sing|Person=3
# Word: शहर, Lemma: शहर, POS: NOUN, Morphology: Case=Acc|Gender=Masc|Number=Sing|Person=3
# Word: के, Lemma: का, POS: ADP, Morphology: AdpType=Post
# Word: ऊपर, Lemma: ऊपर, POS: ADP, Morphology: AdpType=Post|Case=Nom|Gender=Masc|Number=Sing|Person=3
# Word: 19, Lemma: 19, POS: NUM, Morphology: NumType=Card
# Word: मीटर, Lemma: मीटर, POS: NOUN, Morphology: Case=Acc|Gender=Masc|Number=Sing|Person=3
# Word: के, Lemma: का, POS: ADP, Morphology: AdpType=Post|Case=Acc|Gender=Masc|Number=Sing
# Word: क्षुद्रग्रह, Lemma: क्षुद्रग्रह, POS: NOUN, Morphology: Case=Acc|Gender=Masc|Number=Sing|Person=3
# Word: में, Lemma: में, POS: ADP, Morphology: AdpType=Post
# Word: विस्फोट, Lemma: विस्फोट, POS: NOUN, Morphology: Case=Nom|Gender=Masc|Number=Sing|Person=3
# Word: हुआ, Lemma: होना, POS: VERB, Morphology: Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part|Voice=Act
# Word: था, Lemma: था, POS: AUX, Morphology: Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin
# Word: ,, Lemma: ,, POS: PUNCT, Morphology: None
# Word: जिसमें, Lemma: जो, POS: PRON, Morphology: Case=Acc,Ine|Number=Sing|Person=3|PronType=Prs
# Word: 1,200, Lemma: 1200, POS: NUM, Morphology: NumType=Card
# Word: लोग, Lemma: लोग, POS: NOUN, Morphology: Case=Nom|Gender=Masc|Number=Plur|Person=3
# Word: घायल, Lemma: घायल, POS: ADJ, Morphology: None
# Word: हो, Lemma: होना, POS: VERB, Morphology: Gender=Masc|Number=Plur|Voice=Act
# Word: गए, Lemma: जाना, POS: AUX, Morphology: Aspect=Perf|Gender=Masc|Number=Plur|VerbForm=Part
# Word: थे, Lemma: था, POS: AUX, Morphology: Gender=Masc|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin
# Word: ,, Lemma: ,, POS: PUNCT, Morphology: None
# Word: ये, Lemma: यह, POS: PRON, Morphology: Case=Nom|Number=Plur|Person=3|PronType=Prs
# Word: मध्यम, Lemma: मध्यम, POS: ADJ, Morphology: Case=Acc
# Word: आकार, Lemma: आकार, POS: NOUN, Morphology: Case=Acc|Gender=Masc|Number=Sing|Person=3
# Word: के, Lemma: का, POS: ADP, Morphology: AdpType=Post|Case=Nom|Gender=Masc|Number=Plur
# Word: क्षुद्रग्रह, Lemma: क्षुद्रग्रह, POS: NOUN, Morphology: Case=Nom|Gender=Masc|Number=Plur|Person=3
# Word: यदि, Lemma: यदि, POS: SCONJ, Morphology: None
# Word: पृथ्वी, Lemma: पृथ्वी, POS: PROPN, Morphology: Case=Acc|Gender=Fem|Number=Sing|Person=3
# Word: की, Lemma: का, POS: ADP, Morphology: AdpType=Post|Case=Acc|Gender=Fem|Number=Sing
# Word: कक्षा, Lemma: कक्षा, POS: NOUN, Morphology: Case=Acc|Gender=Fem|Number=Sing|Person=3
# Word: में, Lemma: में, POS: ADP, Morphology: AdpType=Post
# Word: प्रवेश, Lemma: प्रवेश, POS: NOUN, Morphology: Case=Nom|Gender=Masc|Number=Sing|Person=3
# Word: करते, Lemma: करना, POS: VERB, Morphology: Aspect=Imp|Gender=Masc|Number=Plur|Person=3|VerbForm=Part|Voice=Act
# Word: हैं, Lemma: है, POS: AUX, Morphology: Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin
# Word: तो, Lemma: तो, POS: SCONJ, Morphology: None
# Word: एक, Lemma: एक, POS: NUM, Morphology: NumType=Card
# Word: गंभीर, Lemma: गंभीर, POS: ADJ, Morphology: Case=Nom
# Word: खतरा, Lemma: खतरा, POS: NOUN, Morphology: Case=Nom|Gender=Masc|Number=Sing|Person=3
# Word: होंगे, Lemma: होना, POS: VERB, Morphology: Gender=Masc|Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin|Voice=Act
# Word: ।, Lemma: ।, POS: PUNCT, Morphology: None
#
# POS Tagging (Stanza + Rule-Based):
# Word: 2010, POS Tag: PROPN
# Word: में, POS Tag: ADP
# Word: ,, POS Tag: PUNCT
# Word: नासा, POS Tag: PROPN
# Word: की, POS Tag: ADP
# Word: ग्रह, POS Tag: PROPN
# Word: रक्षा, POS Tag: PROPN
# Word: टीम, POS Tag: PROPN
# Word: ने, POS Tag: ADP
# Word: पृथ्वी, POS Tag: PROPN
# Word: के, POS Tag: ADP
# Word: पास, POS Tag: ADP
# Word: 1, POS Tag: NUM
# Word: किमी, POS Tag: NOUN
# Word: चौड़े, POS Tag: ADJ
# Word: 90, POS Tag: NUM
# Word: प्रतिशत, POS Tag: NOUN
# Word: क्षुद्रग्रहों, POS Tag: NOUN
# Word: की, POS Tag: ADP
# Word: पहचान, POS Tag: NOUN
# Word: की, POS Tag: VERB
# Word: थी, POS Tag: AUX
# Word: और, POS Tag: CCONJ
# Word: उन्हें, POS Tag: PRON
# Word: लॉग, POS Tag: X
# Word: किया, POS Tag: VERB
# Word: था, POS Tag: AUX
# Word: ।, POS Tag: PUNCT
# Word: ये, POS Tag: PRON
# Word: ', POS Tag: PUNCT
# Word: पृथ्वी, POS Tag: NOUN
# Word: के, POS Tag: ADP
# Word: निकट, POS Tag: ADP
# Word: की, POS Tag: ADP
# Word: वस्तुएं, POS Tag: NOUN
# Word: ', POS Tag: PUNCT
# Word: या, POS Tag: CCONJ
# Word: NEO, POS Tag: PROPN
# Word: ,, POS Tag: PUNCT
# Word: पहाड़ों, POS Tag: NOUN
# Word: के, POS Tag: ADP
# Word: आकार, POS Tag: NOUN
# Word: की, POS Tag: ADP
# Word: हैं, POS Tag: AUX
# Word: और, POS Tag: CCONJ
# Word: इनमें, POS Tag: PRON
# Word: पृथ्वी, POS Tag: PROPN
# Word: की, POS Tag: ADP
# Word: कक्षा, POS Tag: NOUN
# Word: के, POS Tag: ADP
# Word: 50, POS Tag: NUM
# Word: मिलियन, POS Tag: NUM
# Word: किलोमीटर, POS Tag: NOUN
# Word: के, POS Tag: ADP
# Word: भीतर, POS Tag: ADP
# Word: की, POS Tag: ADP
# Word: कोई, POS Tag: PRON
# Word: भी, POS Tag: PART
# Word: चीज़, POS Tag: NOUN
# Word: शामिल, POS Tag: ADJ
# Word: है, POS Tag: AUX
# Word: ।, POS Tag: PUNCT
# Word: लॉग, POS Tag: NOUN
# Word: इन, POS Tag: X
# Word: करने, POS Tag: VERB
# Word: के, POS Tag: ADP
# Word: लिए, POS Tag: ADP
# Word: अनुमानित, POS Tag: ADJ
# Word: 50, POS Tag: NUM
# Word: शेष, POS Tag: ADJ
# Word: होने, POS Tag: VERB
# Word: पर, POS Tag: ADP
# Word: ,, POS Tag: PUNCT
# Word: नासा, POS Tag: PROPN
# Word: का, POS Tag: ADP
# Word: कहना, POS Tag: VERB
# Word: है, POS Tag: AUX
# Word: कि, POS Tag: SCONJ
# Word: जिन, POS Tag: DET
# Word: 887, POS Tag: NUM
# Word: के, POS Tag: ADP
# Word: बारे, POS Tag: ADP
# Word: में, POS Tag: ADP
# Word: वह, POS Tag: PRON
# Word: जानता, POS Tag: VERB
# Word: है, POS Tag: AUX
# Word: उनमें, POS Tag: PRON
# Word: से, POS Tag: ADP
# Word: कोई, POS Tag: PRON
# Word: भी, POS Tag: PART
# Word: ग्रह, POS Tag: NOUN
# Word: के, POS Tag: ADP
# Word: लिए, POS Tag: ADP
# Word: महत्वपूर्ण, POS Tag: ADJ
# Word: खतरा, POS Tag: NOUN
# Word: नहीं, POS Tag: PART
# Word: है, POS Tag: AUX
# Word: ।, POS Tag: PUNCT
# Word: अब, POS Tag: PRON
# Word: नासा, POS Tag: PROPN
# Word: कुछ, POS Tag: DET
# Word: छोटे, POS Tag: ADJ
# Word: क्षुद्रग्रहों, POS Tag: NOUN
# Word: को, POS Tag: ADP
# Word: लॉग, POS Tag: X
# Word: करने, POS Tag: VERB
# Word: की, POS Tag: ADP
# Word: दिशा, POS Tag: NOUN
# Word: में, POS Tag: ADP
# Word: काम, POS Tag: NOUN
# Word: कर, POS Tag: VERB
# Word: रहा, POS Tag: AUX
# Word: है, POS Tag: AUX
# Word: ,, POS Tag: PUNCT
# Word: जिनकी, POS Tag: PRON
# Word: चौड़ाई, POS Tag: NOUN
# Word: 140, POS Tag: NUM
# Word: मीटर, POS Tag: NOUN
# Word: या, POS Tag: CCONJ
# Word: उससे, POS Tag: PRON
# Word: अधिक, POS Tag: DET
# Word: है, POS Tag: AUX
# Word: ।, POS Tag: PUNCT
# Word: इस, POS Tag: DET
# Word: आकार, POS Tag: NOUN
# Word: के, POS Tag: ADP
# Word: 25,000, POS Tag: NUM
# Word: अनुमानित, POS Tag: ADJ
# Word: क्षुद्रग्रहों, POS Tag: NOUN
# Word: में, POS Tag: ADP
# Word: से, POS Tag: ADP
# Word: ,, POS Tag: PUNCT
# Word: अब, POS Tag: PRON
# Word: तक, POS Tag: ADP
# Word: लगभग, POS Tag: PART
# Word: 8,000, POS Tag: NUM
# Word: को, POS Tag: ADP
# Word: लॉग, POS Tag: X
# Word: किया, POS Tag: VERB
# Word: जा, POS Tag: AUX
# Word: चुका, POS Tag: VERB
# Word: है, POS Tag: AUX
# Word: ,, POS Tag: PUNCT
# Word: 17,000, POS Tag: NUM
# Word: को, POS Tag: ADP
# Word: छोड़, POS Tag: VERB
# Word: दिया, POS Tag: VERB
# Word: गया, POS Tag: AUX
# Word: है, POS Tag: AUX
# Word: ।, POS Tag: PUNCT
# Word: यह, POS Tag: PRON
# Word: देखते, POS Tag: VERB
# Word: हुए, POS Tag: AUX
# Word: कि, POS Tag: SCONJ
# Word: 2013, POS Tag: PROPN
# Word: में, POS Tag: ADP
# Word: रूस, POS Tag: PROPN
# Word: के, POS Tag: ADP
# Word: चेल्याबिंस्क, POS Tag: PROPN
# Word: शहर, POS Tag: NOUN
# Word: के, POS Tag: ADP
# Word: ऊपर, POS Tag: ADP
# Word: 19, POS Tag: NUM
# Word: मीटर, POS Tag: NOUN
# Word: के, POS Tag: ADP
# Word: क्षुद्रग्रह, POS Tag: NOUN
# Word: में, POS Tag: ADP
# Word: विस्फोट, POS Tag: NOUN
# Word: हुआ, POS Tag: VERB
# Word: था, POS Tag: AUX
# Word: ,, POS Tag: PUNCT
# Word: जिसमें, POS Tag: PRON
# Word: 1,200, POS Tag: NUM
# Word: लोग, POS Tag: NOUN
# Word: घायल, POS Tag: ADJ
# Word: हो, POS Tag: VERB
# Word: गए, POS Tag: AUX
# Word: थे, POS Tag: AUX
# Word: ,, POS Tag: PUNCT
# Word: ये, POS Tag: PRON
# Word: मध्यम, POS Tag: ADJ
# Word: आकार, POS Tag: NOUN
# Word: के, POS Tag: ADP
# Word: क्षुद्रग्रह, POS Tag: NOUN
# Word: यदि, POS Tag: SCONJ
# Word: पृथ्वी, POS Tag: PROPN
# Word: की, POS Tag: ADP
# Word: कक्षा, POS Tag: NOUN
# Word: में, POS Tag: ADP
# Word: प्रवेश, POS Tag: NOUN
# Word: करते, POS Tag: VERB
# Word: हैं, POS Tag: AUX
# Word: तो, POS Tag: SCONJ
# Word: एक, POS Tag: NUM
# Word: गंभीर, POS Tag: ADJ
# Word: खतरा, POS Tag: NOUN
# Word: होंगे, POS Tag: VERB
# Word: ।, POS Tag: PUNCT
#
# Chunking (Noun and Verb Phrases):
# Sentence 1 Chunks:
#   NP: 2010
#   NP: नासा
#   NP: ग्रह रक्षा टीम
#   NP: पृथ्वी
#   NP: किमी
#   NP: प्रतिशत क्षुद्रग्रहों
#   NP: पहचान
#   VP: की
#   VP: थी
#   VP: किया
#   VP: था
# Sentence 2 Chunks:
#   NP: पृथ्वी
#   NP: वस्तुएं
#   NP: NEO
#   NP: पहाड़ों
#   NP: आकार
#   VP: हैं
#   NP: पृथ्वी
#   NP: कक्षा
#   NP: किलोमीटर
#   NP: चीज़
#   VP: है
# Sentence 3 Chunks:
#   NP: लॉग
#   VP: करने
#   VP: होने
#   NP: नासा
#   VP: कहना
#   VP: है
#   VP: जानता
#   VP: है
#   NP: ग्रह
#   NP: खतरा
#   VP: है
# Sentence 4 Chunks:
#   NP: नासा
#   NP: क्षुद्रग्रहों
#   VP: करने
#   NP: दिशा
#   NP: काम
#   VP: कर
#   VP: रहा
#   VP: है
#   NP: चौड़ाई
#   NP: मीटर
#   VP: है
# Sentence 5 Chunks:
#   NP: आकार
#   NP: क्षुद्रग्रहों
#   VP: किया
#   VP: जा
#   VP: चुका
#   VP: है
#   VP: छोड़
#   VP: दिया
#   VP: गया
#   VP: है
# Sentence 6 Chunks:
#   VP: देखते
#   VP: हुए
#   NP: 2013
#   NP: रूस
#   NP: चेल्याबिंस्क शहर
#   NP: मीटर
#   NP: क्षुद्रग्रह
#   NP: विस्फोट
#   VP: हुआ
#   VP: था
#   NP: लोग
#   VP: हो
#   VP: गए
#   VP: थे
#   NP: आकार
#   NP: क्षुद्रग्रह
#   NP: पृथ्वी
#   NP: कक्षा
#   NP: प्रवेश
#   VP: करते
#   VP: हैं
#   NP: खतरा
#   VP: होंगे
# Recognized Entities:
# Entity: पृथ्वी, Type: LOCATION
# Entity: चेल्याबिंस्क, Type: LOCATION
# Entity: रूस, Type: LOCATION
# Entity: नासा, Type: ORGANIZATION
# Entity: क्षुद्रग्रह, Type: DOMAIN_ENTITY
# Entity: ग्रह, Type: DOMAIN_ENTITY
# Entity: कक्षा, Type: DOMAIN_ENTITY
# Entity: वस्तुएं, Type: DOMAIN_ENTITY
# Entity: 2010, Type: DATE
# Entity: 2013, Type: DATE
# Entity: 1, Type: QUANTITY
# Entity: 90, Type: QUANTITY
# Entity: 50, Type: QUANTITY
# Entity: 50, Type: QUANTITY
# Entity: 887, Type: QUANTITY
# Entity: 140, Type: QUANTITY
# Entity: 25,000, Type: QUANTITY
# Entity: 8,000, Type: QUANTITY
# Entity: 17,000, Type: QUANTITY
# Entity: 19, Type: QUANTITY
# Entity: 1,200, Type: QUANTITY

# %% [markdown]
# # Marathi Experiments

# %%
# Install necessary libraries (uncomment these lines to install in your environment)
# !pip install indic-nlp-library
# !pip install stanza

# Import libraries
from indicnlp.tokenize import indic_tokenize
import stanza

# Download the Stanza model for Marathi (uncomment if not downloaded)
# stanza.download('mr')

# Define stopwords for Marathi directly in the code
marathi_stopwords = [
    "आहे", "आहेत", "होते", "होता", "असे", "मध्ये", "आणि", "किंवा", "तर", "पण",
    "हे", "ही", "का", "नाही", "काय", "मी", "आम्ही", "तुम्ही", "तो", "ती", "ते",
    "यांचा", "यांची", "त्यांचा", "त्यांची", "यात", "त्यात", "मध्ये", "म्हणून",
    "ने", "च्या", "ह्या", "की", "कोणतीही", "ना", "जर", "यामध्ये", "येत्या", "वर",
    "इतके", "पासून", "सोबत", "यासाठी", "या"
]

# Define the NASA-related Marathi text
nasa_marathi_text = """
2010 मध्ये, नासाच्या ग्रह संरक्षण टीमने पृथ्वीच्या जवळ 1 किमी रुंद 90 टक्के क्षुद्रग्रहांची ओळख करून त्यांची नोंद केली.
हे 'पृथ्वीच्या जवळच्या वस्तू' किंवा NEO म्हणून ओळखले जातात, ज्यांचे आकार पर्वतांप्रमाणे आहेत आणि यात पृथ्वीच्या कक्षेत 50 दशलक्ष किलोमीटरच्या आत असलेली कोणतीही वस्तू समाविष्ट आहे.
नोंद करण्यासाठी अंदाजे 50 उरले असल्यास, नासाचे म्हणणे आहे की त्याला माहित असलेल्या 887 मध्ये कोणताही ग्रहासाठी महत्त्वाचा धोका नाही.
आता नासा काही लहान क्षुद्रग्रहांची नोंद करण्यासाठी काम करत आहे, ज्याची रुंदी 140 मीटर किंवा त्याहून अधिक आहे.
या आकाराच्या 25,000 क्षुद्रग्रहांपैकी, आतापर्यंत सुमारे 8,000 नोंदवले गेले आहेत, तर 17,000 टाकले गेले आहेत.
2013 मध्ये रशियाच्या चेल्याबिंस्क शहराच्या वर 19 मीटरच्या क्षुद्रग्रहाचा विस्फोट झाला होता, ज्यात 1,200 लोक जखमी झाले होते, त्यामुळे हे मध्यम आकाराचे क्षुद्रग्रह पृथ्वीच्या कक्षेत प्रवेश केल्यास गंभीर धोका बनू शकतात.
"""

# Tokenization using Indic NLP for Marathi
nasa_marathi_tokens = indic_tokenize.trivial_tokenize(nasa_marathi_text, lang='mr')
print("NASA Marathi Tokens:", nasa_marathi_tokens)

# Stanza Pipeline for Marathi
nlp_marathi = stanza.Pipeline('mr')
doc_nasa_marathi = nlp_marathi(nasa_marathi_text)
nasa_marathi_lemmas = [word.lemma for sent in doc_nasa_marathi.sentences for word in sent.words]
print("NASA Marathi Lemmas:", nasa_marathi_lemmas)

# Filter out Marathi stopwords
filtered_nasa_marathi_tokens = [token for token in nasa_marathi_tokens if token not in marathi_stopwords]
print("Filtered NASA Marathi Tokens:", filtered_nasa_marathi_tokens)
# Out:
# 2024-11-05 23:52:48 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# NASA Marathi Tokens: ['\n2010', 'मध्ये', ',', 'नासाच्या', 'ग्रह', 'संरक्षण', 'टीमने', 'पृथ्वीच्या', 'जवळ', '1', 'किमी', 'रुंद', '90', 'टक्के', 'क्षुद्रग्रहांची', 'ओळख', 'करून', 'त्यांची', 'नोंद', 'केली', '.', '\nहे', "'", 'पृथ्वीच्या', 'जवळच्या', 'वस्तू', "'", 'किंवा', 'NEO', 'म्हणून', 'ओळखले', 'जातात', ',', 'ज्यांचे', 'आकार', 'पर्वतांप्रमाणे', 'आहेत', 'आणि', 'यात', 'पृथ्वीच्या', 'कक्षेत', '50', 'दशलक्ष', 'किलोमीटरच्या', 'आत', 'असलेली', 'कोणतीही', 'वस्तू', 'समाविष्ट', 'आहे', '.', '\nनोंद', 'करण्यासाठी', 'अंदाजे', '50', 'उरले', 'असल्यास', ',', 'नासाचे', 'म्हणणे', 'आहे', 'की', 'त्याला', 'माहित', 'असलेल्या', '887', 'मध्ये', 'कोणताही', 'ग्रहासाठी', 'महत्त्वाचा', 'धोका', 'नाही', '.', '\nआता', 'नासा', 'काही', 'लहान', 'क्षुद्रग्रहांची', 'नोंद', 'करण्यासाठी', 'काम', 'करत', 'आहे', ',', 'ज्याची', 'रुंदी', '140', 'मीटर', 'किंवा', 'त्याहून', 'अधिक', 'आहे', '.', '\nया', 'आकाराच्या', '25,000', 'क्षुद्रग्रहांपैकी', ',', 'आतापर्यंत', 'सुमारे', '8,000', 'नोंदवले', 'गेले', 'आहेत', ',', 'तर', '17,000', 'टाकले', 'गेले', 'आहेत', '.', '\n2013', 'मध्ये', 'रशियाच्या', 'चेल्याबिंस्क', 'शहराच्या', 'वर', '19', 'मीटरच्या', 'क्षुद्रग्रहाचा', 'विस्फोट', 'झाला', 'होता', ',', 'ज्यात', '1,200', 'लोक', 'जखमी', 'झाले', 'होते', ',', 'त्यामुळे', 'हे', 'मध्यम', 'आकाराचे', 'क्षुद्रग्रह', 'पृथ्वीच्या', 'कक्षेत', 'प्रवेश', 'केल्यास', 'गंभीर', 'धोका', 'बनू', 'शकतात', '.', '\n']
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.9.0.json:   0%|   …
# 2024-11-05 23:52:49 INFO: Downloaded file to C:\Users\91636\stanza_resources\resources.json
# Downloading https://huggingface.co/stanfordnlp/stanza-mr/resolve/v1.9.0/models/tokenize/ufal.pt:   0%|        …
# Downloading https://huggingface.co/stanfordnlp/stanza-mr/resolve/v1.9.0/models/mwt/ufal.pt:   0%|          | 0…
# Downloading https://huggingface.co/stanfordnlp/stanza-mr/resolve/v1.9.0/models/pos/ufal_charlm.pt:   0%|      …
# Downloading https://huggingface.co/stanfordnlp/stanza-mr/resolve/v1.9.0/models/lemma/ufal_nocharlm.pt:   0%|  …
# Downloading https://huggingface.co/stanfordnlp/stanza-mr/resolve/v1.9.0/models/depparse/ufal_charlm.pt:   0%| …
# Downloading https://huggingface.co/stanfordnlp/stanza-mr/resolve/v1.9.0/models/sentiment/l3cube_charlm.pt:   0…
# Downloading https://huggingface.co/stanfordnlp/stanza-mr/resolve/v1.9.0/models/ner/l3cube.pt:   0%|          |…
# Downloading https://huggingface.co/stanfordnlp/stanza-mr/resolve/v1.9.0/models/forward_charlm/l3cube.pt:   0%|…
# Downloading https://huggingface.co/stanfordnlp/stanza-mr/resolve/v1.9.0/models/backward_charlm/l3cube.pt:   0%…
# Downloading https://huggingface.co/stanfordnlp/stanza-mr/resolve/v1.9.0/models/pretrain/fasttextwiki.pt:   0%|…
# 2024-11-05 23:57:06 INFO: Loading these models for language: mr (Marathi):
# =============================
# | Processor | Package       |
# -----------------------------
# | tokenize  | ufal          |
# | mwt       | ufal          |
# | pos       | ufal_charlm   |
# | lemma     | ufal_nocharlm |
# | depparse  | ufal_charlm   |
# | sentiment | l3cube_charlm |
# | ner       | l3cube        |
# =============================
#
# 2024-11-05 23:57:06 INFO: Using device: cpu
# 2024-11-05 23:57:06 INFO: Loading: tokenize
# 2024-11-05 23:57:06 INFO: Loading: mwt
# c:\Users\91636\anaconda3\Lib\site-packages\stanza\models\mwt\trainer.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2024-11-05 23:57:06 INFO: Loading: pos
# 2024-11-05 23:57:07 INFO: Loading: lemma
# 2024-11-05 23:57:07 INFO: Loading: depparse
# 2024-11-05 23:57:08 INFO: Loading: sentiment
# c:\Users\91636\anaconda3\Lib\site-packages\stanza\models\classifiers\trainer.py:72: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2024-11-05 23:57:09 INFO: Loading: ner
# c:\Users\91636\anaconda3\Lib\site-packages\stanza\models\ner\trainer.py:197: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2024-11-05 23:57:11 INFO: Done loading processors!
# NASA Marathi Lemmas: ['2010', 'मधे', ',', 'नास', 'चा', 'ग्रह', 'संरक्षण', 'टीम', 'पृथ्वी', 'चा', 'जवळ', '1', 'किमी', 'रुंद', '90', 'टक्के', 'क्षुद्र', 'चा', 'ओळख', 'करणे', 'तो', 'चा', 'नोंद', 'करणे', '.', 'हा', "'पृथ्वी", 'चा', 'जवळ', 'चा', "वस्तू'", 'किंवा', 'NEO', 'म्हणून', 'ओळखणे', 'जाणे', ',', 'जा', 'चा', 'आकार', 'पर्व', 'प्राणे', 'असणे', 'आणि', 'यात', 'पृथ्वी', 'चा', 'कक्षेत', '50', 'दशलक्ष', 'किलोमी', 'आत', 'असणे', 'कोणती', 'हा', 'वस्तू', 'समाविष्ट', 'असणे', '.', 'नोंद', 'करणे', 'साठी', 'अंदाजे', '50', 'उरणे', 'असल्यास', ',', 'नास', 'चा', 'म्हणणे', 'असणे', 'की', 'तो', 'माहित', 'असलेल्या', '887', 'मधे', 'कोणता', 'ही', 'ग्रहास', 'ठी', 'महत्त्वा', 'चा', 'धोक', 'असणे', '.', 'आता', 'नास', 'काही', 'लहान', 'क्षुद्र', 'चा', 'नोंद', 'करणे', 'साठी', 'काम', 'करणे', 'असणे', ',', 'जा', 'चा', 'रुंदी', '140', 'मीटर', 'किंवा', 'त्याहून', 'अधिक', 'असणे', '.', 'हा', 'आकार', 'चा', '25', ',', '000', 'क्षुद्र', ',', 'आतापर्यं', 'तत', 'सुमार', '8,', '000', 'नोंदवले', 'जाणे', 'असणे', ',', 'तर', '17,', '000', 'टाकणे', 'जाणे', 'असणे', '.', '2013', 'मधे', 'रशिय', 'चा', 'चेला', 'बिसस्', 'शहर', 'चा', 'वर', '19', 'मीटर', 'चा', 'क्षुद्र', 'चा', 'विस्फोट', 'होणे', 'असणे', ',', 'जा', '1,', '200', 'लोक', 'जखमा', 'होणे', 'असणे', ',', 'त्यामुळे', 'हा', 'मध्यम', 'आकार', 'चा', 'क्षुद्रग्रह', 'पृथ्वी', 'चा', 'कक्ष', 'प्रवणे', 'करणे', 'गंभीर', 'धोक', 'बनणे', 'शकणे', '.']
# Filtered NASA Marathi Tokens: ['\n2010', ',', 'नासाच्या', 'ग्रह', 'संरक्षण', 'टीमने', 'पृथ्वीच्या', 'जवळ', '1', 'किमी', 'रुंद', '90', 'टक्के', 'क्षुद्रग्रहांची', 'ओळख', 'करून', 'नोंद', 'केली', '.', '\nहे', "'", 'पृथ्वीच्या', 'जवळच्या', 'वस्तू', "'", 'NEO', 'ओळखले', 'जातात', ',', 'ज्यांचे', 'आकार', 'पर्वतांप्रमाणे', 'पृथ्वीच्या', 'कक्षेत', '50', 'दशलक्ष', 'किलोमीटरच्या', 'आत', 'असलेली', 'वस्तू', 'समाविष्ट', '.', '\nनोंद', 'करण्यासाठी', 'अंदाजे', '50', 'उरले', 'असल्यास', ',', 'नासाचे', 'म्हणणे', 'त्याला', 'माहित', 'असलेल्या', '887', 'कोणताही', 'ग्रहासाठी', 'महत्त्वाचा', 'धोका', '.', '\nआता', 'नासा', 'काही', 'लहान', 'क्षुद्रग्रहांची', 'नोंद', 'करण्यासाठी', 'काम', 'करत', ',', 'ज्याची', 'रुंदी', '140', 'मीटर', 'त्याहून', 'अधिक', '.', '\nया', 'आकाराच्या', '25,000', 'क्षुद्रग्रहांपैकी', ',', 'आतापर्यंत', 'सुमारे', '8,000', 'नोंदवले', 'गेले', ',', '17,000', 'टाकले', 'गेले', '.', '\n2013', 'रशियाच्या', 'चेल्याबिंस्क', 'शहराच्या', '19', 'मीटरच्या', 'क्षुद्रग्रहाचा', 'विस्फोट', 'झाला', ',', 'ज्यात', '1,200', 'लोक', 'जखमी', 'झाले', ',', 'त्यामुळे', 'मध्यम', 'आकाराचे', 'क्षुद्रग्रह', 'पृथ्वीच्या', 'कक्षेत', 'प्रवेश', 'केल्यास', 'गंभीर', 'धोका', 'बनू', 'शकतात', '.', '\n']

# %%
# Import necessary libraries
from indicnlp.tokenize import indic_tokenize
import stanza
import re

# Download necessary resources for Marathi
# Uncomment the following line if you haven't downloaded the model yet
# stanza.download('mr')

# Define the Marathi text for processing
text_for_processing = """
2010 मध्ये, नासाच्या ग्रह संरक्षण टीमने पृथ्वीच्या जवळ 1 किमी रुंद 90 टक्के क्षुद्रग्रहांची ओळख करून त्यांची नोंद केली.
हे 'पृथ्वीच्या जवळच्या वस्तू' किंवा NEO म्हणून ओळखले जातात, ज्यांचे आकार पर्वतांप्रमाणे आहेत आणि यात पृथ्वीच्या कक्षेत 50 दशलक्ष किलोमीटरच्या आत असलेली कोणतीही वस्तू समाविष्ट आहे.
नोंद करण्यासाठी अंदाजे 50 उरले असल्यास, नासाचे म्हणणे आहे की त्याला माहित असलेल्या 887 मध्ये कोणताही ग्रहासाठी महत्त्वाचा धोका नाही.
आता नासा काही लहान क्षुद्रग्रहांची नोंद करण्यासाठी काम करत आहे, ज्याची रुंदी 140 मीटर किंवा त्याहून अधिक आहे.
या आकाराच्या 25,000 क्षुद्रग्रहांपैकी, आतापर्यंत सुमारे 8,000 नोंदवले गेले आहेत, तर 17,000 टाकले गेले आहेत.
2013 मध्ये रशियाच्या चेल्याबिंस्क शहराच्या वर 19 मीटरच्या क्षुद्रग्रहाचा विस्फोट झाला होता, ज्यात 1,200 लोक जखमी झाले होते, त्यामुळे हे मध्यम आकाराचे क्षुद्रग्रह पृथ्वीच्या कक्षेत प्रवेश केल्यास गंभीर धोका बनू शकतात.
"""

# Initialize Stanza Pipeline for Marathi
nlp_marathi = stanza.Pipeline('mr')

# Process the text using Stanza
doc = nlp_marathi(text_for_processing)

# 1. Morphological Analysis
print("Morphological Analysis:")
for sentence in doc.sentences:
    for word in sentence.words:
        print(f"Word: {word.text}, Lemma: {word.lemma}, POS: {word.pos}, Morphology: {word.feats}")

# 2. POS Tagging (Rule-Based)
print("\nPOS Tagging (Stanza + Rule-Based):")
for sentence in doc.sentences:
    for word in sentence.words:
        pos_tag = word.pos
        # Basic rule-based adjustments if needed
        if word.text in ["आहे", "आहेत"]:  # Recognize auxiliary verbs
            pos_tag = "AUX"
        print(f"Word: {word.text}, POS Tag: {pos_tag}")

# 3. Chunking (Noun and Verb Phrases)
print("\nChunking (Noun and Verb Phrases):")
chunked_sentences = []
for sentence in doc.sentences:
    chunked_sentence = []
    current_chunk = []
    for word in sentence.words:
        if word.pos in ["NOUN", "PROPN"]:  # Noun Phrase
            current_chunk.append(word.text)
        elif current_chunk:
            chunked_sentence.append(("NP", " ".join(current_chunk)))
            current_chunk = []
        if word.pos in ["VERB", "AUX"]:  # Verb Phrase
            chunked_sentence.append(("VP", word.text))
    if current_chunk:  # Append any remaining noun phrase
        chunked_sentence.append(("NP", " ".join(current_chunk)))
    chunked_sentences.append(chunked_sentence)

# Display chunked sentences
for i, chunks in enumerate(chunked_sentences):
    print(f"Sentence {i+1} Chunks:")
    for chunk_type, chunk_text in chunks:
        print(f"  {chunk_type}: {chunk_text}")

# 4. Named Entity Recognition (NER)
# Predefined lists of known entities specific to the text
KNOWN_LOCATIONS = ["पृथ्वी", "चेल्याबिंस्क", "रूस"]
KNOWN_ORGANIZATIONS = ["नासा"]
KNOWN_ENTITY_TYPES = ["क्षुद्रग्रह", "ग्रह", "कक्षा", "वस्तू"]

# Rule-based NER function
def rule_based_ner(text):
    entities = []

    # Match predefined locations
    for location in KNOWN_LOCATIONS:
        if location in text:
            entities.append({'entity': location, 'type': 'LOCATION'})

    # Match predefined organizations
    for org in KNOWN_ORGANIZATIONS:
        if org in text:
            entities.append({'entity': org, 'type': 'ORGANIZATION'})

    # Match other domain-specific entity types
    for entity_type in KNOWN_ENTITY_TYPES:
        if entity_type in text:
            entities.append({'entity': entity_type, 'type': 'DOMAIN_ENTITY'})

    # Regex pattern for detecting years and large numbers (e.g., 2010, 50 million, 25,000)
    years = re.findall(r'\b\d{4}\b', text)
    for year in years:
        entities.append({'entity': year, 'type': 'DATE'})

    # Regex for large numbers
    large_numbers = re.findall(r'\b\d{1,3}(?:,\d{3})*\b', text)
    for number in large_numbers:
        entities.append({'entity': number, 'type': 'QUANTITY'})

    return entities

# Perform rule-based NER
ner_results = rule_based_ner(text_for_processing)

# Print recognized entities
print("Recognized Entities:")
for entity in ner_results:
    print(f"Entity: {entity['entity']}, Type: {entity['type']}")
# Out:
# 2024-11-05 23:57:16 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.9.0.json:   0%|   …
# 2024-11-05 23:57:18 INFO: Downloaded file to C:\Users\91636\stanza_resources\resources.json
# 2024-11-05 23:57:22 INFO: Loading these models for language: mr (Marathi):
# =============================
# | Processor | Package       |
# -----------------------------
# | tokenize  | ufal          |
# | mwt       | ufal          |
# | pos       | ufal_charlm   |
# | lemma     | ufal_nocharlm |
# | depparse  | ufal_charlm   |
# | sentiment | l3cube_charlm |
# | ner       | l3cube        |
# =============================
#
# 2024-11-05 23:57:22 INFO: Using device: cpu
# 2024-11-05 23:57:22 INFO: Loading: tokenize
# 2024-11-05 23:57:22 INFO: Loading: mwt
# 2024-11-05 23:57:22 INFO: Loading: pos
# 2024-11-05 23:57:23 INFO: Loading: lemma
# 2024-11-05 23:57:23 INFO: Loading: depparse
# 2024-11-05 23:57:24 INFO: Loading: sentiment
# 2024-11-05 23:57:25 INFO: Loading: ner
# 2024-11-05 23:57:27 INFO: Done loading processors!
# Morphological Analysis:
# Word: 2010, Lemma: 2010, POS: PROPN, Morphology: Case=Nom|Gender=Masc|Number=Sing
# Word: मध्ये, Lemma: मधे, POS: ADV, Morphology: None
# Word: ,, Lemma: ,, POS: PUNCT, Morphology: None
# Word: नासा, Lemma: नास, POS: PROPN, Morphology: Case=Abs|Gender=Fem|Number=Sing
# Word: च्या, Lemma: चा, POS: ADP, Morphology: Case=Abs
# Word: ग्रह, Lemma: ग्रह, POS: NOUN, Morphology: Case=Nom|Gender=Masc|Number=Sing
# Word: संरक्षण, Lemma: संरक्षण, POS: NOUN, Morphology: Case=Nom|Gender=Neut|Number=Sing
# Word: टीमने, Lemma: टीम, POS: NOUN, Morphology: Case=Ins|Gender=Masc|Number=Sing
# Word: पृथ्वी, Lemma: पृथ्वी, POS: NOUN, Morphology: Case=Abs|Gender=Fem|Number=Sing
# Word: च्या, Lemma: चा, POS: PART, Morphology: None
# Word: जवळ, Lemma: जवळ, POS: ADP, Morphology: None
# Word: 1, Lemma: 1, POS: NUM, Morphology: None
# Word: किमी, Lemma: किमी, POS: NUM, Morphology: None
# Word: रुंद, Lemma: रुंद, POS: NOUN, Morphology: Case=Acc|Gender=Masc|Number=Plur
# Word: 90, Lemma: 90, POS: NUM, Morphology: None
# Word: टक्के, Lemma: टक्के, POS: ADJ, Morphology: Case=Nom|Number=Plur
# Word: क्षुद्र्रा, Lemma: क्षुद्र, POS: NOUN, Morphology: Case=Abs|Gender=Masc|Number=Sing
# Word: ची, Lemma: चा, POS: ADP, Morphology: Gender=Fem|Number=Sing
# Word: ओळख, Lemma: ओळख, POS: NOUN, Morphology: Case=Acc|Gender=Fem|Number=Sing
# Word: करून, Lemma: करणे, POS: VERB, Morphology: Aspect=Perf|VerbForm=Conv
# Word: त्यां, Lemma: तो, POS: PRON, Morphology: Deixis=Remt|Gender=Masc|Number=Plur|Person=3|PronType=Dem
# Word: ची, Lemma: चा, POS: ADP, Morphology: Gender=Fem|Number=Sing
# Word: नोंद, Lemma: नोंद, POS: NOUN, Morphology: Case=Nom|Gender=Fem|Number=Sing
# Word: केली, Lemma: करणे, POS: VERB, Morphology: Aspect=Perf|Gender=Fem|Number=Sing|Person=3|VerbForm=Fin
# Word: ., Lemma: ., POS: PUNCT, Morphology: None
# Word: हे, Lemma: हा, POS: DET, Morphology: Deixis=Prox|Gender=Neut|Number=Sing|PronType=Dem
# Word: 'पृथ्वी, Lemma: 'पृथ्वी, POS: NOUN, Morphology: Case=Abs|Gender=Fem|Number=Sing
# Word: च्या, Lemma: चा, POS: ADP, Morphology: Case=Abs
# Word: जवळ, Lemma: जवळ, POS: ADP, Morphology: None
# Word: च्या, Lemma: चा, POS: ADP, Morphology: Case=Abs
# Word: वस्तू', Lemma: वस्तू', POS: NOUN, Morphology: Case=Nom|Gender=Neut|Number=Plur
# Word: किंवा, Lemma: किंवा, POS: CCONJ, Morphology: None
# Word: NEO, Lemma: NEO, POS: NOUN, Morphology: Case=Nom|Gender=Neut|Number=Sing
# Word: म्हणून, Lemma: म्हणून, POS: CCONJ, Morphology: None
# Word: ओळखले, Lemma: ओळखणे, POS: VERB, Morphology: Aspect=Perf|Gender=Neut|Number=Plur|Person=3|VerbForm=Fin
# Word: जातात, Lemma: जाणे, POS: VERB, Morphology: Aspect=Imp|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin
# Word: ,, Lemma: ,, POS: PUNCT, Morphology: None
# Word: ज्या, Lemma: जा, POS: PRON, Morphology: Deixis=Remt|Gender=Masc|Number=Sing|Person=3|PronType=Dem
# Word: चे, Lemma: चा, POS: ADP, Morphology: Gender=Masc|Number=Plur
# Word: आकार, Lemma: आकार, POS: NOUN, Morphology: Case=Nom|Gender=Masc|Number=Plur
# Word: पर्वां, Lemma: पर्व, POS: NOUN, Morphology: Case=Nom|Gender=Masc|Number=Sing
# Word: प्राणे, Lemma: प्राणे, POS: NOUN, Morphology: Case=Nom|Gender=Masc|Number=Sing
# Word: आहेत, Lemma: असणे, POS: AUX, Morphology: Number=Plur|Person=3|Polarity=Pos|Tense=Pres|VerbForm=Fin
# Word: आणि, Lemma: आणि, POS: CCONJ, Morphology: None
# Word: यात, Lemma: यात, POS: ADV, Morphology: None
# Word: पृथ्वी, Lemma: पृथ्वी, POS: NOUN, Morphology: Case=Abs|Gender=Fem|Number=Sing
# Word: च्या, Lemma: चा, POS: PART, Morphology: None
# Word: कक्षेत, Lemma: कक्षेत, POS: ADP, Morphology: None
# Word: 50, Lemma: 50, POS: NUM, Morphology: None
# Word: दशलक्ष, Lemma: दशलक्ष, POS: ADJ, Morphology: Case=Nom|Gender=Neut|Number=Plur
# Word: किलोमीटरच्या, Lemma: किलोमी, POS: NUM, Morphology: None
# Word: आत, Lemma: आत, POS: ADV, Morphology: None
# Word: असलेली, Lemma: असणे, POS: AUX, Morphology: Gender=Neut|Number=Sing|Person=3|Polarity=Pos|Tense=Past|VerbForm=Fin
# Word: कोणती, Lemma: कोणती, POS: ADJ, Morphology: Case=Nom|Gender=Neut|Number=Plur
# Word: ही, Lemma: हा, POS: DET, Morphology: Deixis=Prox|Gender=Fem|Number=Sing|PronType=Dem
# Word: वस्तू, Lemma: वस्तू, POS: NOUN, Morphology: Case=Nom|Gender=Fem|Number=Sing
# Word: समाविष्ट, Lemma: समाविष्ट, POS: ADJ, Morphology: Case=Nom
# Word: आहे, Lemma: असणे, POS: AUX, Morphology: Number=Sing|Person=3|Polarity=Pos|Tense=Pres|VerbForm=Fin
# Word: ., Lemma: ., POS: PUNCT, Morphology: None
# Word: नोंद, Lemma: नोंद, POS: NOUN, Morphology: Case=Nom|Gender=Fem|Number=Sing
# Word: करण्या, Lemma: करणे, POS: VERB, Morphology: Case=Abs|InfForm=Dict|VerbForm=Inf
# Word: साठी, Lemma: साठी, POS: ADP, Morphology: None
# Word: अंदाजे, Lemma: अंदाजे, POS: ADJ, Morphology: Case=Nom|Gender=Neut|Number=Sing
# Word: 50, Lemma: 50, POS: NUM, Morphology: None
# Word: उरले, Lemma: उरणे, POS: VERB, Morphology: Aspect=Perf|Gender=Neut|Number=Sing|Person=3|VerbForm=Fin
# Word: असल्यास, Lemma: असल्यास, POS: SCONJ, Morphology: None
# Word: ,, Lemma: ,, POS: PUNCT, Morphology: None
# Word: नासा, Lemma: नास, POS: NOUN, Morphology: Case=Abs|Gender=Neut|Number=Sing
# Word: चे, Lemma: चा, POS: ADP, Morphology: Gender=Neut|Number=Sing
# Word: म्हणणे, Lemma: म्हणणे, POS: NOUN, Morphology: Case=Nom|Gender=Neut|Number=Sing
# Word: आहे, Lemma: असणे, POS: AUX, Morphology: Number=Sing|Person=3|Polarity=Pos|Tense=Pres|VerbForm=Fin
# Word: की, Lemma: की, POS: SCONJ, Morphology: None
# Word: त्याला, Lemma: तो, POS: PRON, Morphology: Case=Dat|Deixis=Remt|Gender=Masc|Number=Sing|Person=3|PronType=Dem
# Word: माहित, Lemma: माहित, POS: ADV, Morphology: None
# Word: असलेल्या, Lemma: असलेल्या, POS: CCONJ, Morphology: None
# Word: 887, Lemma: 887, POS: PROPN, Morphology: Case=Nom|Gender=Masc|Number=Sing
# Word: मध्ये, Lemma: मधे, POS: ADV, Morphology: None
# Word: कोणता, Lemma: कोणता, POS: PRON, Morphology: Gender=Masc|Number=Sing|PronType=Int
# Word: ही, Lemma: ही, POS: PART, Morphology: None
# Word: ग्रहासा, Lemma: ग्रहास, POS: NOUN, Morphology: Case=Abs|Gender=Masc|Number=Sing
# Word: ठी, Lemma: ठी, POS: NOUN, Morphology: Case=Nom|Gender=Fem|Number=Sing
# Word: महत्त्वा, Lemma: महत्त्वा, POS: NOUN, Morphology: Case=Abs|Gender=Masc|Number=Sing
# Word: चा, Lemma: चा, POS: ADP, Morphology: Gender=Masc|Number=Sing
# Word: धोका, Lemma: धोक, POS: NOUN, Morphology: Case=Nom|Gender=Masc|Number=Sing
# Word: नाही, Lemma: असणे, POS: AUX, Morphology: Number=Sing|Person=3|Polarity=Neg|VerbForm=Fin
# Word: ., Lemma: ., POS: PUNCT, Morphology: None
# Word: आता, Lemma: आता, POS: ADV, Morphology: None
# Word: नासा, Lemma: नास, POS: NOUN, Morphology: Case=Abs|Gender=Neut|Number=Sing
# Word: काही, Lemma: काही, POS: DET, Morphology: Number=Sing|PronType=Ind
# Word: लहान, Lemma: लहान, POS: ADJ, Morphology: Case=Abs
# Word: क्षुद्र्रा, Lemma: क्षुद्र, POS: NOUN, Morphology: Case=Abs|Gender=Neut|Number=Sing
# Word: ची, Lemma: चा, POS: ADP, Morphology: Gender=Fem|Number=Sing
# Word: नोंद, Lemma: नोंद, POS: NOUN, Morphology: Case=Nom|Gender=Fem|Number=Sing
# Word: करण्या, Lemma: करणे, POS: VERB, Morphology: Case=Abs|InfForm=Dict|VerbForm=Inf
# Word: साठी, Lemma: साठी, POS: ADP, Morphology: None
# Word: काम, Lemma: काम, POS: NOUN, Morphology: Case=Nom|Gender=Fem|Number=Sing
# Word: करत, Lemma: करणे, POS: VERB, Morphology: Aspect=Imp|VerbForm=Part
# Word: आहे, Lemma: असणे, POS: AUX, Morphology: Number=Sing|Person=3|Polarity=Pos|Tense=Pres|VerbForm=Fin
# Word: ,, Lemma: ,, POS: PUNCT, Morphology: None
# Word: ज्या, Lemma: जा, POS: PRON, Morphology: Deixis=Remt|Gender=Masc|Number=Sing|Person=3|PronType=Dem
# Word: ची, Lemma: चा, POS: ADP, Morphology: Gender=Fem|Number=Sing
# Word: रुंदी, Lemma: रुंदी, POS: NOUN, Morphology: Case=Nom|Gender=Fem|Number=Sing
# Word: 140, Lemma: 140, POS: NUM, Morphology: None
# Word: मीटर, Lemma: मीटर, POS: ADJ, Morphology: Case=Nom|Gender=Neut|Number=Plur
# Word: किंवा, Lemma: किंवा, POS: CCONJ, Morphology: None
# Word: त्याहून, Lemma: त्याहून, POS: ADV, Morphology: None
# Word: अधिक, Lemma: अधिक, POS: ADJ, Morphology: Case=Nom
# Word: आहे, Lemma: असणे, POS: AUX, Morphology: Number=Sing|Person=3|Polarity=Pos|Tense=Pres|VerbForm=Fin
# Word: ., Lemma: ., POS: PUNCT, Morphology: None
# Word: या, Lemma: हा, POS: DET, Morphology: Case=Abs|Deixis=Prox|PronType=Dem
# Word: आकारा, Lemma: आकार, POS: NOUN, Morphology: Case=Abs|Gender=Neut|Number=Sing
# Word: च्या, Lemma: चा, POS: PART, Morphology: None
# Word: 25, Lemma: 25, POS: NUM, Morphology: None
# Word: ,, Lemma: ,, POS: PUNCT, Morphology: None
# Word: 000, Lemma: 000, POS: ADJ, Morphology: Case=Nom|Gender=Neut|Number=Plur
# Word: क्षुद्रग्रहांपैकी, Lemma: क्षुद्र, POS: NOUN, Morphology: Case=Nom|Gender=Neut|Number=Plur
# Word: ,, Lemma: ,, POS: PUNCT, Morphology: None
# Word: आतापर्यं, Lemma: आतापर्यं, POS: ADJ, Morphology: Case=Abs
# Word: तत, Lemma: तत, POS: ADP, Morphology: None
# Word: सुमारे, Lemma: सुमार, POS: NUM, Morphology: None
# Word: 8,, Lemma: 8,, POS: ADJ, Morphology: Case=Nom
# Word: 000, Lemma: 000, POS: ADJ, Morphology: Case=Nom
# Word: नोंदवले, Lemma: नोंदवले, POS: ADJ, Morphology: Case=Nom
# Word: गेले, Lemma: जाणे, POS: AUX, Morphology: Gender=Masc|Number=Plur|Person=3|VerbForm=Fin
# Word: आहेत, Lemma: असणे, POS: AUX, Morphology: Number=Plur|Person=3|Polarity=Pos|Tense=Pres|VerbForm=Fin
# Word: ,, Lemma: ,, POS: PUNCT, Morphology: None
# Word: तर, Lemma: तर, POS: CCONJ, Morphology: None
# Word: 17,, Lemma: 17,, POS: CCONJ, Morphology: None
# Word: 000, Lemma: 000, POS: PROPN, Morphology: Case=Nom|Gender=Masc|Number=Sing
# Word: टाकले, Lemma: टाकणे, POS: VERB, Morphology: Aspect=Perf|Gender=Masc|Number=Plur|Person=3|VerbForm=Fin
# Word: गेले, Lemma: जाणे, POS: AUX, Morphology: Aspect=Perf|Gender=Masc|Number=Plur|Person=3|VerbForm=Fin
# Word: आहेत, Lemma: असणे, POS: AUX, Morphology: Number=Plur|Person=3|Polarity=Pos|Tense=Pres|VerbForm=Fin
# Word: ., Lemma: ., POS: PUNCT, Morphology: None
# Word: 2013, Lemma: 2013, POS: PROPN, Morphology: Case=Abs|Gender=Masc|Number=Sing
# Word: मध्ये, Lemma: मधे, POS: ADV, Morphology: None
# Word: रशिया, Lemma: रशिय, POS: NOUN, Morphology: Case=Abs|Gender=Masc|Number=Sing
# Word: च्या, Lemma: चा, POS: PART, Morphology: None
# Word: चेल्या, Lemma: चेला, POS: PROPN, Morphology: Case=Nom|Gender=Fem|Number=Sing
# Word: बिसस्, Lemma: बिसस्, POS: PROPN, Morphology: Case=Nom|Gender=Masc|Number=Sing
# Word: शहरा, Lemma: शहर, POS: NOUN, Morphology: Case=Abs|Gender=Neut|Number=Sing
# Word: च्या, Lemma: चा, POS: PART, Morphology: None
# Word: वर, Lemma: वर, POS: ADP, Morphology: None
# Word: 19, Lemma: 19, POS: NUM, Morphology: None
# Word: मीटर, Lemma: मीटर, POS: NOUN, Morphology: Case=Abs|Gender=Fem|Number=Plur
# Word: च्या, Lemma: चा, POS: ADP, Morphology: Case=Abs
# Word: क्षुद्र्रा, Lemma: क्षुद्र, POS: NOUN, Morphology: Case=Abs|Gender=Masc|Number=Sing
# Word: चा, Lemma: चा, POS: ADP, Morphology: Gender=Masc|Number=Sing
# Word: विस्फोट, Lemma: विस्फोट, POS: NOUN, Morphology: Case=Nom|Gender=Masc|Number=Sing
# Word: झाला, Lemma: होणे, POS: VERB, Morphology: Aspect=Perf|Gender=Masc|Number=Sing|Person=3|VerbForm=Fin
# Word: होता, Lemma: असणे, POS: AUX, Morphology: Gender=Masc|Number=Sing|Person=3|Polarity=Pos|Tense=Past|VerbForm=Fin
# Word: ,, Lemma: ,, POS: PUNCT, Morphology: None
# Word: ज्यात, Lemma: जा, POS: CCONJ, Morphology: None
# Word: 1,, Lemma: 1,, POS: CCONJ, Morphology: None
# Word: 200, Lemma: 200, POS: NUM, Morphology: None
# Word: लोक, Lemma: लोक, POS: NOUN, Morphology: Case=Nom|Gender=Masc|Number=Plur
# Word: जखमी, Lemma: जखमा, POS: ADJ, Morphology: Case=Nom
# Word: झाले, Lemma: होणे, POS: VERB, Morphology: Aspect=Perf|Gender=Masc|Number=Plur|Person=3|VerbForm=Fin
# Word: होते, Lemma: असणे, POS: AUX, Morphology: Gender=Masc|Number=Plur|Person=3|Polarity=Pos|Tense=Past|VerbForm=Fin
# Word: ,, Lemma: ,, POS: PUNCT, Morphology: None
# Word: त्यामुळे, Lemma: त्यामुळे, POS: CCONJ, Morphology: None
# Word: हे, Lemma: हा, POS: DET, Morphology: Deixis=Prox|Gender=Neut|Number=Sing|PronType=Dem
# Word: मध्यम, Lemma: मध्यम, POS: ADJ, Morphology: Case=Nom
# Word: आकारा, Lemma: आकार, POS: NOUN, Morphology: Case=Abs|Gender=Neut|Number=Sing
# Word: चे, Lemma: चा, POS: ADP, Morphology: Gender=Neut|Number=Sing
# Word: क्षुद्रग्रह, Lemma: क्षुद्रग्रह, POS: NOUN, Morphology: Case=Nom|Gender=Neut|Number=Sing
# Word: पृथ्वी, Lemma: पृथ्वी, POS: NOUN, Morphology: Case=Abs|Gender=Fem|Number=Sing
# Word: च्या, Lemma: चा, POS: PART, Morphology: None
# Word: कक्षेत, Lemma: कक्ष, POS: NOUN, Morphology: Case=Loc|Gender=Neut|Number=Sing
# Word: प्रवेश, Lemma: प्रवणे, POS: VERB, Morphology: Aspect=Imp|VerbForm=Part
# Word: केल्यास, Lemma: करणे, POS: VERB, Morphology: Aspect=Perf|VerbForm=Conv
# Word: गंभीर, Lemma: गंभीर, POS: ADV, Morphology: None
# Word: धोका, Lemma: धोक, POS: NOUN, Morphology: Case=Nom|Gender=Masc|Number=Sing
# Word: बनू, Lemma: बनणे, POS: VERB, Morphology: InfForm=Incp|VerbForm=Inf
# Word: शकतात, Lemma: शकणे, POS: AUX, Morphology: Number=Plur|Person=3|Polarity=Neg|Tense=Fut|VerbForm=Fin
# Word: ., Lemma: ., POS: PUNCT, Morphology: None
#
# POS Tagging (Stanza + Rule-Based):
# Word: 2010, POS Tag: PROPN
# Word: मध्ये, POS Tag: ADV
# Word: ,, POS Tag: PUNCT
# Word: नासा, POS Tag: PROPN
# Word: च्या, POS Tag: ADP
# Word: ग्रह, POS Tag: NOUN
# Word: संरक्षण, POS Tag: NOUN
# Word: टीमने, POS Tag: NOUN
# Word: पृथ्वी, POS Tag: NOUN
# Word: च्या, POS Tag: PART
# Word: जवळ, POS Tag: ADP
# Word: 1, POS Tag: NUM
# Word: किमी, POS Tag: NUM
# Word: रुंद, POS Tag: NOUN
# Word: 90, POS Tag: NUM
# Word: टक्के, POS Tag: ADJ
# Word: क्षुद्र्रा, POS Tag: NOUN
# Word: ची, POS Tag: ADP
# Word: ओळख, POS Tag: NOUN
# Word: करून, POS Tag: VERB
# Word: त्यां, POS Tag: PRON
# Word: ची, POS Tag: ADP
# Word: नोंद, POS Tag: NOUN
# Word: केली, POS Tag: VERB
# Word: ., POS Tag: PUNCT
# Word: हे, POS Tag: DET
# Word: 'पृथ्वी, POS Tag: NOUN
# Word: च्या, POS Tag: ADP
# Word: जवळ, POS Tag: ADP
# Word: च्या, POS Tag: ADP
# Word: वस्तू', POS Tag: NOUN
# Word: किंवा, POS Tag: CCONJ
# Word: NEO, POS Tag: NOUN
# Word: म्हणून, POS Tag: CCONJ
# Word: ओळखले, POS Tag: VERB
# Word: जातात, POS Tag: VERB
# Word: ,, POS Tag: PUNCT
# Word: ज्या, POS Tag: PRON
# Word: चे, POS Tag: ADP
# Word: आकार, POS Tag: NOUN
# Word: पर्वां, POS Tag: NOUN
# Word: प्राणे, POS Tag: NOUN
# Word: आहेत, POS Tag: AUX
# Word: आणि, POS Tag: CCONJ
# Word: यात, POS Tag: ADV
# Word: पृथ्वी, POS Tag: NOUN
# Word: च्या, POS Tag: PART
# Word: कक्षेत, POS Tag: ADP
# Word: 50, POS Tag: NUM
# Word: दशलक्ष, POS Tag: ADJ
# Word: किलोमीटरच्या, POS Tag: NUM
# Word: आत, POS Tag: ADV
# Word: असलेली, POS Tag: AUX
# Word: कोणती, POS Tag: ADJ
# Word: ही, POS Tag: DET
# Word: वस्तू, POS Tag: NOUN
# Word: समाविष्ट, POS Tag: ADJ
# Word: आहे, POS Tag: AUX
# Word: ., POS Tag: PUNCT
# Word: नोंद, POS Tag: NOUN
# Word: करण्या, POS Tag: VERB
# Word: साठी, POS Tag: ADP
# Word: अंदाजे, POS Tag: ADJ
# Word: 50, POS Tag: NUM
# Word: उरले, POS Tag: VERB
# Word: असल्यास, POS Tag: SCONJ
# Word: ,, POS Tag: PUNCT
# Word: नासा, POS Tag: NOUN
# Word: चे, POS Tag: ADP
# Word: म्हणणे, POS Tag: NOUN
# Word: आहे, POS Tag: AUX
# Word: की, POS Tag: SCONJ
# Word: त्याला, POS Tag: PRON
# Word: माहित, POS Tag: ADV
# Word: असलेल्या, POS Tag: CCONJ
# Word: 887, POS Tag: PROPN
# Word: मध्ये, POS Tag: ADV
# Word: कोणता, POS Tag: PRON
# Word: ही, POS Tag: PART
# Word: ग्रहासा, POS Tag: NOUN
# Word: ठी, POS Tag: NOUN
# Word: महत्त्वा, POS Tag: NOUN
# Word: चा, POS Tag: ADP
# Word: धोका, POS Tag: NOUN
# Word: नाही, POS Tag: AUX
# Word: ., POS Tag: PUNCT
# Word: आता, POS Tag: ADV
# Word: नासा, POS Tag: NOUN
# Word: काही, POS Tag: DET
# Word: लहान, POS Tag: ADJ
# Word: क्षुद्र्रा, POS Tag: NOUN
# Word: ची, POS Tag: ADP
# Word: नोंद, POS Tag: NOUN
# Word: करण्या, POS Tag: VERB
# Word: साठी, POS Tag: ADP
# Word: काम, POS Tag: NOUN
# Word: करत, POS Tag: VERB
# Word: आहे, POS Tag: AUX
# Word: ,, POS Tag: PUNCT
# Word: ज्या, POS Tag: PRON
# Word: ची, POS Tag: ADP
# Word: रुंदी, POS Tag: NOUN
# Word: 140, POS Tag: NUM
# Word: मीटर, POS Tag: ADJ
# Word: किंवा, POS Tag: CCONJ
# Word: त्याहून, POS Tag: ADV
# Word: अधिक, POS Tag: ADJ
# Word: आहे, POS Tag: AUX
# Word: ., POS Tag: PUNCT
# Word: या, POS Tag: DET
# Word: आकारा, POS Tag: NOUN
# Word: च्या, POS Tag: PART
# Word: 25, POS Tag: NUM
# Word: ,, POS Tag: PUNCT
# Word: 000, POS Tag: ADJ
# Word: क्षुद्रग्रहांपैकी, POS Tag: NOUN
# Word: ,, POS Tag: PUNCT
# Word: आतापर्यं, POS Tag: ADJ
# Word: तत, POS Tag: ADP
# Word: सुमारे, POS Tag: NUM
# Word: 8,, POS Tag: ADJ
# Word: 000, POS Tag: ADJ
# Word: नोंदवले, POS Tag: ADJ
# Word: गेले, POS Tag: AUX
# Word: आहेत, POS Tag: AUX
# Word: ,, POS Tag: PUNCT
# Word: तर, POS Tag: CCONJ
# Word: 17,, POS Tag: CCONJ
# Word: 000, POS Tag: PROPN
# Word: टाकले, POS Tag: VERB
# Word: गेले, POS Tag: AUX
# Word: आहेत, POS Tag: AUX
# Word: ., POS Tag: PUNCT
# Word: 2013, POS Tag: PROPN
# Word: मध्ये, POS Tag: ADV
# Word: रशिया, POS Tag: NOUN
# Word: च्या, POS Tag: PART
# Word: चेल्या, POS Tag: PROPN
# Word: बिसस्, POS Tag: PROPN
# Word: शहरा, POS Tag: NOUN
# Word: च्या, POS Tag: PART
# Word: वर, POS Tag: ADP
# Word: 19, POS Tag: NUM
# Word: मीटर, POS Tag: NOUN
# Word: च्या, POS Tag: ADP
# Word: क्षुद्र्रा, POS Tag: NOUN
# Word: चा, POS Tag: ADP
# Word: विस्फोट, POS Tag: NOUN
# Word: झाला, POS Tag: VERB
# Word: होता, POS Tag: AUX
# Word: ,, POS Tag: PUNCT
# Word: ज्यात, POS Tag: CCONJ
# Word: 1,, POS Tag: CCONJ
# Word: 200, POS Tag: NUM
# Word: लोक, POS Tag: NOUN
# Word: जखमी, POS Tag: ADJ
# Word: झाले, POS Tag: VERB
# Word: होते, POS Tag: AUX
# Word: ,, POS Tag: PUNCT
# Word: त्यामुळे, POS Tag: CCONJ
# Word: हे, POS Tag: DET
# Word: मध्यम, POS Tag: ADJ
# Word: आकारा, POS Tag: NOUN
# Word: चे, POS Tag: ADP
# Word: क्षुद्रग्रह, POS Tag: NOUN
# Word: पृथ्वी, POS Tag: NOUN
# Word: च्या, POS Tag: PART
# Word: कक्षेत, POS Tag: NOUN
# Word: प्रवेश, POS Tag: VERB
# Word: केल्यास, POS Tag: VERB
# Word: गंभीर, POS Tag: ADV
# Word: धोका, POS Tag: NOUN
# Word: बनू, POS Tag: VERB
# Word: शकतात, POS Tag: AUX
# Word: ., POS Tag: PUNCT
#
# Chunking (Noun and Verb Phrases):
# Sentence 1 Chunks:
#   NP: 2010
#   NP: नासा
#   NP: ग्रह संरक्षण टीमने पृथ्वी
#   NP: रुंद
#   NP: क्षुद्र्रा
#   NP: ओळख
#   VP: करून
#   NP: नोंद
#   VP: केली
# Sentence 2 Chunks:
#   NP: 'पृथ्वी
#   NP: वस्तू'
#   NP: NEO
#   VP: ओळखले
#   VP: जातात
#   NP: आकार पर्वां प्राणे
#   VP: आहेत
#   NP: पृथ्वी
#   VP: असलेली
#   NP: वस्तू
#   VP: आहे
# Sentence 3 Chunks:
#   NP: नोंद
#   VP: करण्या
#   VP: उरले
#   NP: नासा
#   NP: म्हणणे
#   VP: आहे
#   NP: 887
#   NP: ग्रहासा ठी महत्त्वा
#   NP: धोका
#   VP: नाही
# Sentence 4 Chunks:
#   NP: नासा
#   NP: क्षुद्र्रा
#   NP: नोंद
#   VP: करण्या
#   NP: काम
#   VP: करत
#   VP: आहे
#   NP: रुंदी
#   VP: आहे
# Sentence 5 Chunks:
#   NP: आकारा
#   NP: क्षुद्रग्रहांपैकी
#   VP: गेले
#   VP: आहेत
#   NP: 000
#   VP: टाकले
#   VP: गेले
#   VP: आहेत
# Sentence 6 Chunks:
#   NP: 2013
#   NP: रशिया
#   NP: चेल्या बिसस् शहरा
#   NP: मीटर
#   NP: क्षुद्र्रा
#   NP: विस्फोट
#   VP: झाला
#   VP: होता
#   NP: लोक
#   VP: झाले
#   VP: होते
#   NP: आकारा
#   NP: क्षुद्रग्रह पृथ्वी
#   NP: कक्षेत
#   VP: प्रवेश
#   VP: केल्यास
#   NP: धोका
#   VP: बनू
#   VP: शकतात
# Recognized Entities:
# Entity: पृथ्वी, Type: LOCATION
# Entity: चेल्याबिंस्क, Type: LOCATION
# Entity: नासा, Type: ORGANIZATION
# Entity: क्षुद्रग्रह, Type: DOMAIN_ENTITY
# Entity: ग्रह, Type: DOMAIN_ENTITY
# Entity: वस्तू, Type: DOMAIN_ENTITY
# Entity: 2010, Type: DATE
# Entity: 2013, Type: DATE
# Entity: 1, Type: QUANTITY
# Entity: 90, Type: QUANTITY
# Entity: 50, Type: QUANTITY
# Entity: 50, Type: QUANTITY
# Entity: 887, Type: QUANTITY
# Entity: 140, Type: QUANTITY
# Entity: 25,000, Type: QUANTITY
# Entity: 8,000, Type: QUANTITY
# Entity: 17,000, Type: QUANTITY
# Entity: 19, Type: QUANTITY
# Entity: 1,200, Type: QUANTITY

# %% [markdown]
# # Gujrati

# %%
# Install necessary libraries (uncomment these lines to install in your environment)
# !pip install indic-nlp-library

# Import libraries
from indicnlp.tokenize import indic_tokenize

# Define stopwords for Gujarati directly in the code
gujarati_stopwords = [
    "છે", "છે", "હોય", "હોય", "તમે", "કેમ", "પણ", "અને", "કે", "કેવું",
    "આ", "આવ", "તે", "તેને", "કેવી", "થવા", "છે", "ની", "કેટલાક", "જો",
    "ત્યારે", "ફરી", "કિંવાં", "હવે", "વસે", "આમ", "આય", "તન", "નહીં",
    "યે", "કરવા", "કરતા", "કરતી", "જ્યાં", "આજ", "નવો", "દૂર", "જાણવા"
]

# Define the NASA-related Gujarati text
nasa_gujarati_text = """
2010માં, નાસાની ગ્રહ સંરક્ષણ ટીમે પૃથ્વીના નજીક 1 કિમી પહોળા 90 ટકાના ક્ષુદ્રગ્રહોની ઓળખ કરી અને તેમનો નોટ કર્યો.
આને 'પૃથ્વીના નજીકની વસ્તુઓ' અથવા NEO તરીકે ઓળખવામાં આવે છે, જે પહાડોના કદની છે અને તેમાં પૃથ્વીના કક્ષામાં 50 મિલિયન કિલોમીટર દ્વારા આવેલું કોઈ પણ વસ્તુ સમાવિષ્ટ છે.
નોંધ લેવા માટે અંદાજે 50 બચ્યા છે, નાસાનું કહેવું છે કે તે જાણતા 887 માંથી કોઈપણ ગ્રહ માટે મહત્ત્વનો ખતરો નથી.
હવે નાસા કેટલાક નાના ક્ષુદ્રગ્રહોને નોંધવા માટે કામ કરી રહ્યો છે, જેણે પહોળાઈ 140 મીટર કે તેથી વધુ છે.
આ કદના 25,000 ક્ષુદ્રગ્રહોમાંથી, અત્યાર સુધીમાં લગભગ 8,000 નોંધાયા છે, 17,000 છોડાઈ ગયા છે.
2013 માં રશિયાના ચેલ્યાબિન્સ્ક શહેરની ઉપર 19 મીટર ના ક્ષુદ્રગ્રહમાં વિસ્ફોટ થયો હતો, જેમાં 1,200 લોકો ઘાયલ થયા હતા, તેથી આ મધ્યમ કદના ક્ષુદ્રગ્રહો પૃથ્વીની કક્ષામાં પ્રવેશ કરે તો ગંભીર ખતરો બની શકે છે.
"""

# Tokenization using Indic NLP for Gujarati
nasa_gujarati_tokens = indic_tokenize.trivial_tokenize(nasa_gujarati_text, lang='gu')
print("NASA Gujarati Tokens:", nasa_gujarati_tokens)

# Filter out Gujarati stopwords
filtered_nasa_gujarati_tokens = [token for token in nasa_gujarati_tokens if token not in gujarati_stopwords]
print("Filtered NASA Gujarati Tokens:", filtered_nasa_gujarati_tokens)
# Out:
# NASA Gujarati Tokens: ['\n2010માં', ',', 'નાસાની', 'ગ્રહ', 'સંરક્ષણ', 'ટીમે', 'પૃથ્વીના', 'નજીક', '1', 'કિમી', 'પહોળા', '90', 'ટકાના', 'ક્ષુદ્રગ્રહોની', 'ઓળખ', 'કરી', 'અને', 'તેમનો', 'નોટ', 'કર્યો', '.', '\nઆને', "'", 'પૃથ્વીના', 'નજીકની', 'વસ્તુઓ', "'", 'અથવા', 'NEO', 'તરીકે', 'ઓળખવામાં', 'આવે', 'છે', ',', 'જે', 'પહાડોના', 'કદની', 'છે', 'અને', 'તેમાં', 'પૃથ્વીના', 'કક્ષામાં', '50', 'મિલિયન', 'કિલોમીટર', 'દ્વારા', 'આવેલું', 'કોઈ', 'પણ', 'વસ્તુ', 'સમાવિષ્ટ', 'છે', '.', '\nનોંધ', 'લેવા', 'માટે', 'અંદાજે', '50', 'બચ્યા', 'છે', ',', 'નાસાનું', 'કહેવું', 'છે', 'કે', 'તે', 'જાણતા', '887', 'માંથી', 'કોઈપણ', 'ગ્રહ', 'માટે', 'મહત્ત્વનો', 'ખતરો', 'નથી', '.', '\nહવે', 'નાસા', 'કેટલાક', 'નાના', 'ક્ષુદ્રગ્રહોને', 'નોંધવા', 'માટે', 'કામ', 'કરી', 'રહ્યો', 'છે', ',', 'જેણે', 'પહોળાઈ', '140', 'મીટર', 'કે', 'તેથી', 'વધુ', 'છે', '.', '\nઆ', 'કદના', '25,000', 'ક્ષુદ્રગ્રહોમાંથી', ',', 'અત્યાર', 'સુધીમાં', 'લગભગ', '8,000', 'નોંધાયા', 'છે', ',', '17,000', 'છોડાઈ', 'ગયા', 'છે', '.', '\n2013', 'માં', 'રશિયાના', 'ચેલ્યાબિન્સ્ક', 'શહેરની', 'ઉપર', '19', 'મીટર', 'ના', 'ક્ષુદ્રગ્રહમાં', 'વિસ્ફોટ', 'થયો', 'હતો', ',', 'જેમાં', '1,200', 'લોકો', 'ઘાયલ', 'થયા', 'હતા', ',', 'તેથી', 'આ', 'મધ્યમ', 'કદના', 'ક્ષુદ્રગ્રહો', 'પૃથ્વીની', 'કક્ષામાં', 'પ્રવેશ', 'કરે', 'તો', 'ગંભીર', 'ખતરો', 'બની', 'શકે', 'છે', '.', '\n']
# Filtered NASA Gujarati Tokens: ['\n2010માં', ',', 'નાસાની', 'ગ્રહ', 'સંરક્ષણ', 'ટીમે', 'પૃથ્વીના', 'નજીક', '1', 'કિમી', 'પહોળા', '90', 'ટકાના', 'ક્ષુદ્રગ્રહોની', 'ઓળખ', 'કરી', 'તેમનો', 'નોટ', 'કર્યો', '.', '\nઆને', "'", 'પૃથ્વીના', 'નજીકની', 'વસ્તુઓ', "'", 'અથવા', 'NEO', 'તરીકે', 'ઓળખવામાં', 'આવે', ',', 'જે', 'પહાડોના', 'કદની', 'તેમાં', 'પૃથ્વીના', 'કક્ષામાં', '50', 'મિલિયન', 'કિલોમીટર', 'દ્વારા', 'આવેલું', 'કોઈ', 'વસ્તુ', 'સમાવિષ્ટ', '.', '\nનોંધ', 'લેવા', 'માટે', 'અંદાજે', '50', 'બચ્યા', ',', 'નાસાનું', 'કહેવું', 'જાણતા', '887', 'માંથી', 'કોઈપણ', 'ગ્રહ', 'માટે', 'મહત્ત્વનો', 'ખતરો', 'નથી', '.', '\nહવે', 'નાસા', 'નાના', 'ક્ષુદ્રગ્રહોને', 'નોંધવા', 'માટે', 'કામ', 'કરી', 'રહ્યો', ',', 'જેણે', 'પહોળાઈ', '140', 'મીટર', 'તેથી', 'વધુ', '.', '\nઆ', 'કદના', '25,000', 'ક્ષુદ્રગ્રહોમાંથી', ',', 'અત્યાર', 'સુધીમાં', 'લગભગ', '8,000', 'નોંધાયા', ',', '17,000', 'છોડાઈ', 'ગયા', '.', '\n2013', 'માં', 'રશિયાના', 'ચેલ્યાબિન્સ્ક', 'શહેરની', 'ઉપર', '19', 'મીટર', 'ના', 'ક્ષુદ્રગ્રહમાં', 'વિસ્ફોટ', 'થયો', 'હતો', ',', 'જેમાં', '1,200', 'લોકો', 'ઘાયલ', 'થયા', 'હતા', ',', 'તેથી', 'મધ્યમ', 'કદના', 'ક્ષુદ્રગ્રહો', 'પૃથ્વીની', 'કક્ષામાં', 'પ્રવેશ', 'કરે', 'તો', 'ગંભીર', 'ખતરો', 'બની', 'શકે', '.', '\n']

# %%
# Import necessary libraries
from indicnlp.tokenize import indic_tokenize
import stanza
import re

# Download necessary resources for Gujarati
# Uncomment the following line if you haven't downloaded the model yet
# stanza.download('gu')

# Define the Gujarati text for processing
text_for_processing = """
2010 માં, નાસાના ગ્રહ સંરક્ષણ ટીમે પૃથ્વીની નજીક 1 કિમી પહોળા 90 ટકાના ક્ષુદ્રગ્રહોને ઓળખ્યા અને તેમનો નોટ કર્યો.
આને 'પૃથ્વીના નજીકની વસ્તુઓ' અથવા NEO તરીકે ઓળખવામાં આવે છે, જે પહાડોના કદની છે અને તેમાં પૃથ્વીની કક્ષામાં 50 મિલિયન કિલોમીટર દ્વારા આવેલું કોઈ પણ વસ્તુ સમાવિષ્ટ છે.
નોંધ લેવા માટે અંદાજે 50 બચ્યા છે, નાસાનું કહેવું છે કે તે જાણતા 887 માંથી કોઈપણ ગ્રહ માટે મહત્ત્વનો ખતરો નથી.
હવે નાસા કેટલાક નાના ક્ષુદ્રગ્રહોને નોંધવા માટે કામ કરી રહ્યો છે, જેણે પહોળાઈ 140 મીટર કે તેથી વધુ છે.
આ કદના 25,000 ક્ષુદ્રગ્રહોમાંથી, અત્યાર સુધીમાં લગભગ 8,000 નોંધાયા છે, 17,000 છોડાઈ ગયા છે.
2013 માં રશિયાના ચેલ્યાબિન્સ્ક શહેરની ઉપર 19 મીટર ના ક્ષુદ્રગ્રહમાં વિસ્ફોટ થયો હતો, જેમાં 1,200 લોકો ઘાયલ થયા હતા, તેથી આ મધ્યમ કદના ક્ષુદ્રગ્રહો પૃથ્વીની કક્ષામાં પ્રવેશ કરે તો ગંભીર ખતરો બની શકે છે.
"""

# Initialize Stanza Pipeline for Gujarati
nlp_gujarati = stanza.Pipeline('gu')

# Process the text using Stanza
doc = nlp_gujarati(text_for_processing)

# 1. Morphological Analysis
print("Morphological Analysis:")
for sentence in doc.sentences:
    for word in sentence.words:
        print(f"Word: {word.text}, Lemma: {word.lemma}, POS: {word.pos}, Morphology: {word.feats}")

# 2. POS Tagging (Rule-Based)
print("\nPOS Tagging (Stanza + Rule-Based):")
for sentence in doc.sentences:
    for word in sentence.words:
        pos_tag = word.pos
        # Basic rule-based adjustments if needed
        if word.text in ["છે", "છે"]:  # Recognize auxiliary verbs
            pos_tag = "AUX"
        print(f"Word: {word.text}, POS Tag: {pos_tag}")

# 3. Chunking (Noun and Verb Phrases)
print("\nChunking (Noun and Verb Phrases):")
chunked_sentences = []
for sentence in doc.sentences:
    chunked_sentence = []
    current_chunk = []
    for word in sentence.words:
        if word.pos in ["NOUN", "PROPN"]:  # Noun Phrase
            current_chunk.append(word.text)
        elif current_chunk:
            chunked_sentence.append(("NP", " ".join(current_chunk)))
            current_chunk = []
        if word.pos in ["VERB", "AUX"]:  # Verb Phrase
            chunked_sentence.append(("VP", word.text))
    if current_chunk:  # Append any remaining noun phrase
        chunked_sentence.append(("NP", " ".join(current_chunk)))
    chunked_sentences.append(chunked_sentence)

# Display chunked sentences
for i, chunks in enumerate(chunked_sentences):
    print(f"Sentence {i+1} Chunks:")
    for chunk_type, chunk_text in chunks:
        print(f"  {chunk_type}: {chunk_text}")

# 4. Named Entity Recognition (NER)
# Predefined lists of known entities specific to the text
KNOWN_LOCATIONS = ["પૃથ્વી", "ચેલ્યાબિન્સ્ક", "રશિયા"]
KNOWN_ORGANIZATIONS = ["નાસા"]
KNOWN_ENTITY_TYPES = ["ક્ષુદ્રગ્રહ", "ગ્રહ", "કક્ષા", "વસ્તુ"]

# Rule-based NER function
def rule_based_ner(text):
    entities = []

    # Match predefined locations
    for location in KNOWN_LOCATIONS:
        if location in text:
            entities.append({'entity': location, 'type': 'LOCATION'})

    # Match predefined organizations
    for org in KNOWN_ORGANIZATIONS:
        if org in text:
            entities.append({'entity': org, 'type': 'ORGANIZATION'})

    # Match other domain-specific entity types
    for entity_type in KNOWN_ENTITY_TYPES:
        if entity_type in text:
            entities.append({'entity': entity_type, 'type': 'DOMAIN_ENTITY'})

    # Regex pattern for detecting years and large numbers (e.g., 2010, 50 million, 25,000)
    years = re.findall(r'\b\d{4}\b', text)
    for year in years:
        entities.append({'entity': year, 'type': 'DATE'})

    # Regex for large numbers
    large_numbers = re.findall(r'\b\d{1,3}(?:,\d{3})*\b', text)
    for number in large_numbers:
        entities.append({'entity': number, 'type': 'QUANTITY'})

    return entities

# Perform rule-based NER
ner_results = rule_based_ner(text_for_processing)

# Print recognized entities
print("Recognized Entities:")
for entity in ner_results:
    print(f"Entity: {entity['entity']}, Type: {entity['type']}")
# Out:
# 2024-11-05 23:58:40 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.9.0.json:   0%|   …
# 2024-11-05 23:58:40 INFO: Downloaded file to C:\Users\91636\stanza_resources\resources.json
# 2024-11-05 23:58:40 WARNING: Unsupported language: gu  If trying to add a new language, consider using allow_unknown_language=True
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 21
#      11 text_for_processing = """
#      12 2010 માં, નાસાના ગ્રહ સંરક્ષણ ટીમે પૃથ્વીની નજીક 1 કિમી પહોળા 90 ટકાના ક્ષુદ્રગ્રહોને ઓળખ્યા અને તેમનો નોટ કર્યો.
#      13 આને 'પૃથ્વીના નજીકની વસ્તુઓ' અથવા NEO તરીકે ઓળખવામાં આવે છે, જે પહાડોના કદની છે અને તેમાં પૃથ્વીની કક્ષામાં 50 મિલિયન કિલોમીટર દ્વારા આવેલું કોઈ પણ વસ્તુ સમાવિષ્ટ છે.
#    (...)
#      17 2013 માં રશિયાના ચેલ્યાબિન્સ્ક શહેરની ઉપર 19 મીટર ના ક્ષુદ્રગ્રહમાં વિસ્ફોટ થયો હતો, જેમાં 1,200 લોકો ઘાયલ થયા હતા, તેથી આ મધ્યમ કદના ક્ષુદ્રગ્રહો પૃથ્વીની કક્ષામાં પ્રવેશ કરે તો ગંભીર ખતરો બની શકે છે.
#      18 """
#      20 # Initialize Stanza Pipeline for Gujarati
# ---> 21 nlp_gujarati = stanza.Pipeline('gu')
#      23 # Process the text using Stanza
#      24 doc = nlp_gujarati(text_for_processing)
#
# File c:\Users\91636\anaconda3\Lib\site-packages\stanza\pipeline\core.py:267, in Pipeline.__init__(self, lang, dir, package, processors, logging_level, verbose, use_gpu, model_dir, download_method, resources_url, resources_branch, resources_version, resources_filepath, proxies, foundation_cache, device, allow_unknown_language, **kwargs)
#     265 if len(self.load_list) == 0:
#     266     if lang not in resources or PACKAGES not in resources[lang]:
# --> 267         raise ValueError(f'No processors to load for language {lang}.  Language {lang} is currently unsupported')
#     268     else:
#     269         raise ValueError('No processors to load for language {}.  Please check if your language or package is correctly set.'.format(lang))
#
# ValueError: No processors to load for language gu.  Language gu is currently unsupported
